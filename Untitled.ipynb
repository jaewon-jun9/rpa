# %%
#복수의 파일에서 같은 위치의 워크시트에서 같은 셀 주소에 있는 정보들을 보기
setFolder='C:/Users/won-pc30/Desktop/VE/'
# 하위폴더를 포함하여 모든 엑셀 파일을 리스트에 담기
import openpyxl
import glob
import pandas as pd
from excelrange import (excelNum,
                      excelString,
                      cellRange
                      
)
def readCell(addList):
    import openpyxl
    all_values=[]
    for row in range(addList[1],addList[3]+1): #row 단위로 읽기
        row_value=[] #row 마다 셀의 값을 저장
        for cell in range(addList[0],addList[2]+1): #row 마다 cell 단위로 데이터 읽기
            row_value.append(load_ws.cell(row,cell).value) #row_value에 cell의 내용을 넣어주어 row를 완성
        all_values.append(row_value) #row를 전체 리스트에 추가    
    return all_values

targetPattern1 = setFolder+"*.xlsx"
xlsxs=glob.glob(targetPattern1)
print(xlsxs)
#모든 하위폴더 내의 엑셀파일에서 워크시트의 이름 가져오기
allData=[]
num1=cellRange("l4","q17")
num2=cellRange("b3","f7")
num3=cellRange("b10","f14")
num4=cellRange("b18","e23")
num5=cellRange("b33","f36")
for i in xlsxs:
    load_wb = openpyxl.load_workbook(i, data_only=True) # data_only=True 를 선택할 경우 수식이 아닌 값을 가져옴
    allData.append([i]) #문서 내의 시트 이름 보기
    load_ws = load_wb[load_wb.sheetnames[2]] #'세 번째에 위치한 시트 지정
    allData=allData+readCell(num2)
    allData=allData+readCell(num3)
    allData=allData+readCell(num4)
    load_ws = load_wb[load_wb.sheetnames[1]] #'두 번째에 위치한 시트 지정
    allData=allData+readCell(num1)
    load_ws = load_wb[load_wb.sheetnames[2]] #'세 번째에 위치한 시트 지정
    allData=allData+readCell(num5)
# Out:
# ['C:/Users/won-pc30/Desktop/VE\\제안-01상하수01 유량분배 0901.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-02상하수02 생물반응조 유효수심 0901.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-03상하수03 침전지 0919 (민감도 수정).xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-04상하수04 찌꺼기 반송라인 0901.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-05상하수05 총인처리시설 0901.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-06토목01 맨홀뚜껑 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-07토목02 기능성 시멘트 적용 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-08토목03 부력방지용 앵커 0904.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-09토목04 굴착공법 및 가시설계획 0917.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-10토목05 외기노출부 방수공사 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-11토목06 운영실 휴게가든 0904.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-12토목07 엘리베이터, 방풍실 계획 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-13기계01 스크린 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-14기계02 유량조정조 이중수문 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-15기계03 유입펌프 구성 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-16기계04 송풍기실 위치 0915.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-17기계05 호기조 산기장치 0915.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-18기계06 분리막 미세협착물 세척 및 이송 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-19기계07 처리수 이송펌프 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-20기계08 농축기 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-21기계09 탈수 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-22기계10 탈취기 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-23기계11 탈취기실 위치 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-24기계12 재이용계획 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-25기계13 방류펌프 용량 0907.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-26기계14 급기팬룸 설치 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-27기계15 별도 풍도설치 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-28기계16 운영실 전열교환기 설치 0903.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-29전기01 VCB반 설치 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-30전기02 케이블 0902.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-31전기03 케이블 트레이 0904.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-32전기04 역률 개선 0904.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-33전기05 모터보호 계전기 0904.xlsx', 'C:/Users/won-pc30/Desktop/VE\\제안-34전기06 시설물 관리시스템 0902.xlsx']

# %%
allData
# Out:
# [['C:/Users/won-pc30/Desktop/VE\\제안-01상하수01 유량분배 0901.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '합류식, 분리식 하수혼합', None, '합류식, 분리식 하수분리', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 14, 9, 126, 9, 126],
#  ['에너지절감', 16, 7, 112, 9, 144],
#  ['시공성', 14, 9, 126, 9, 126],
#  ['효율성', 22, 7, 154, 9, 198],
#  ['안정성', 19, 7, 133, 10, 190],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 786, None, 919, None],
#  ['LCC', '백만원', 7138.200000000001, None, 6968.2, None],
#  ['성능점수 (P)', None, 78.6, None, 91.9, None],
#  ['상대 LCC (C)', None, 1.024, None, 1, None],
#  ['가치평가 (V=P/C)', None, 76.8, None, 91.9, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 3418, 3700, -282],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 1572.3, 1702, -129.70000000000005],
#  [None, '초기투자비', 4990.3, 5402, -411.6999999999998],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 4990.3, 5402, -411.6999999999998],
#  [None, '유지관리비', 2147.9, 1566.2, 581.7],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 7138.200000000001, 6968.2, 170.0000000000009],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 78.59032548109569, 74.93784149663226],
#  [None, 0.034999999999999996, 74.6266065181101, 72.04762975278861],
#  [None, 0.045, 71.3823612818168, 69.6820342679914],
#  [None, 0.05499999999999999, 68.70634498004608, 67.7307723812836],
#  [None, 0.06499999999999999, 66.48215607982911, 66.1089679748754],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 78.6, 91.9, 0.16921],
#  [None, 'LCC', 1.024, 1, -0.02343],
#  [None, '가치', 76.8, 91.9, 0.19661],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-02상하수02 생물반응조 유효수심 0901.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, 'H=6.0m', None, 'H=8.0m', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 14, 9, 126, 9, 126],
#  ['에너지절감', 16, 9, 144, 9, 144],
#  ['시공성', 14, 7, 98, 9, 126],
#  ['효율성', 22, 7, 154, 9, 198],
#  ['안정성', 19, 9, 171, 9, 171],
#  ['유지관리성', 15, 8, 120, 9, 135],
#  ['총 가중값', None, 813, None, 900, None],
#  ['LCC', '백만원', 12321, None, 11821.6, None],
#  ['성능점수 (P)', None, 81.3, None, 90, None],
#  ['상대 LCC (C)', None, 1.042, None, 1, None],
#  ['가치평가 (V=P/C)', None, 78, None, 90, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 8315, 7978, 337],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 3824.9, 3669.9, 155],
#  [None, '초기투자비', 12139.9, 11647.9, 492],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 12139.9, 11647.9, 492],
#  [None, '유지관리비', 181.1, 173.7, 7.400000000000006],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 12321, 11821.6, 499.39999999999964],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 123.81748099033301, 118.79946596160593],
#  [None, 0.034999999999999996, 123.48332021367503, 118.47884789140483],
#  [None, 0.045, 123.20981456961894, 118.21642675190606],
#  [None, 0.05499999999999999, 122.9842133869671, 117.99996862495192],
#  [None, 0.06499999999999999, 122.79670345064942, 117.82005800071002],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.3, 90, 0.10701],
#  [None, 'LCC', 1.042, 1, -0.0403],
#  [None, '가치', 78, 90, 0.15384],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-03상하수03 침전지 0919 (민감도 수정).xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '재래식 침전지', None, '경사판 침전지', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 14, 9, 126, 9, 126],
#  ['에너지절감', 16, 9, 144, 9, 144],
#  ['시공성', 14, 9, 126, 9, 126],
#  ['효율성', 22, 7, 154, 10, 220],
#  ['안정성', 19, 7, 133, 10, 190],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 818, None, 941, None],
#  ['LCC', '백만원', 3798.9, None, 3272.3, None],
#  ['성능점수 (P)', None, 81.8, None, 94.1, None],
#  ['상대 LCC (C)', None, 1.16, None, 1, None],
#  ['가치평가 (V=P/C)', None, 70.5, None, 94.1, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 2061, 1293, 768],
#  [None, '관급자재비', 734, 684, 50],
#  [None, '제잡비', 948.1, 594.8, 353.30000000000007],
#  [None, '초기투자비', 3743.1, 2571.8, 1171.2999999999997],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 3743.1, 2571.8, 1171.2999999999997],
#  [None, '유지관리비', 55.8, 1014.9, -959.1],
#  [None, '잔존가치비', 0, -314.4, 314.4],
#  [None, '생애주기비', 3798.9, 3272.3, 526.5999999999999],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 38.17669116672423, 35.333989705748415],
#  [None, 0.034999999999999996, 38.07365924693013, 33.94840160355493],
#  [None, 0.045, 37.989329147319225, 32.72273844604805],
#  [None, 0.05499999999999999, 37.91976944857507, 31.654974408261197],
#  [None, 0.06499999999999999, 37.86195443835006, 30.735023423611345],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.8, 94.1, 0.15036],
#  [None, 'LCC', 1.16, 1, -0.13793],
#  [None, '가치', 70.5, 94.1, 0.33475],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-04상하수04 찌꺼기 반송라인 0901.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None,
#   None,
#   '#1분리막조→무산소조\n#2분리막조→혐기조',
#   None,
#   '#1DO저감조→무산소조\n#2무산소조→혐기조',
#   None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 14, 8, 112, 9, 126],
#  ['에너지절감', 16, 9, 144, 9, 144],
#  ['시공성', 14, 8, 112, 9, 126],
#  ['효율성', 22, 7, 154, 9, 198],
#  ['안정성', 19, 8, 152, 9, 171],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 809, None, 900, None],
#  ['LCC', '백만원', 318.09999999999997, None, 254.49999999999997, None],
#  ['성능점수 (P)', None, 80.9, None, 90, None],
#  ['상대 LCC (C)', None, 1.249, None, 1, None],
#  ['가치평가 (V=P/C)', None, 64.8, None, 90, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0, 0],
#  [None, '관급자재비', 250, 200, 50],
#  [None, '제잡비', 0, 0, 0],
#  [None, '초기투자비', 250, 200, 50],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 250, 200, 50],
#  [None, '유지관리비', 98.7, 78.9, 19.799999999999997],
#  [None, '잔존가치비', -30.6, -24.4, -6.200000000000003],
#  [None, '생애주기비', 318.09999999999997, 254.49999999999997, 63.599999999999994],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 3.4347528682001336, 2.747802294560107],
#  [None, 0.034999999999999996, 3.300062369114524, 2.640049895291619],
#  [None, 0.045, 3.1809178830049034, 2.5447343064039227],
#  [None, 0.05499999999999999, 3.0771224831111668, 2.4616979864889332],
#  [None, 0.06499999999999999, 2.9876957212469226, 2.3901565769975384],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 80.9, 90, 0.11248],
#  [None, 'LCC', 1.249, 1, -0.19935],
#  [None, '가치', 64.8, 90, 0.38888],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-05상하수05 총인처리시설 0901.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '응집침전', None, '고속응집침전', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 14, 9, 126, 9, 126],
#  ['에너지절감', 16, 8, 128, 8, 128],
#  ['시공성', 14, 9, 126, 9, 126],
#  ['효율성', 22, 7, 154, 9, 198],
#  ['안정성', 19, 7, 133, 9, 171],
#  ['유지관리성', 15, 9, 135, 8, 120],
#  ['총 가중값', None, 802, None, 869, None],
#  ['LCC', '백만원', 9730.6, None, 9812.400000000001, None],
#  ['성능점수 (P)', None, 80.2, None, 86.9, None],
#  ['상대 LCC (C)', None, 0.991, None, 1, None],
#  ['가치평가 (V=P/C)', None, 80.9, None, 86.9, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '비교안'],
#  [None, '직접공사비', 2475, 2156, 2022],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 1138.5, 991.8, 930.1],
#  [None, '초기투자비', 3613.5, 3147.8, 2952.1],
#  ['2. 생애주기비', None, '원안', '금회제안', '비교안'],
#  [None, '초기투자비', 3613.5, 3147.8, 2952.1],
#  [None, '유지관리비', 6117.1, 6664.6, 5936.656798724361],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 9730.6, 9812.400000000001, 8888.75679872436],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 117.83411235970375, 120.48839600662188],
#  [None, 0.034999999999999996, 106.54577106303437, 108.18985689091382],
#  [None, 0.045, 97.3064309838407, 98.12368486608152],
#  [None, 0.05499999999999999, 89.68535955775621, 89.8206009519763],
#  [None, 0.06499999999999999, 83.35105491901334, 82.91943705880311],
#  ['4. 가치분석', None, '원안', '금회제안', '응집여과'],
#  [None, '성능', 80.2, 86.9, 0.08354],
#  [None, 'LCC', 0.991, 1, 0.00908],
#  [None, '가치', 80.9, 86.9, 0.07416],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-06토목01 맨홀뚜껑 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, 'STS Cover', None, 'FRP Cover', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 17, 7, 119, 9, 153],
#  ['친환경성', 15, 7, 105, 9, 135],
#  ['시공성', 18, 7, 126, 10, 180],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['품질관리성', 14, 7, 98, 9, 126],
#  ['안정성', 21, 9, 189, 8, 168],
#  ['총 가중값', None, 742, None, 897, None],
#  ['LCC', '백만원', 1.6, None, 0.6000000000000001, None],
#  ['성능점수 (P)', None, 74.2, None, 89.7, None],
#  ['상대 LCC (C)', None, 2.666, None, 1, None],
#  ['가치평가 (V=P/C)', None, 27.8, None, 89.7, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 1.1, 0.4, 0.7000000000000001],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 0.5, 0.2, 0.3],
#  [None, '초기투자비', 1.6, 0.6000000000000001, 1],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 1.6, 0.6000000000000001, 1],
#  [None, '유지관리비', 0, 0, 0],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 1.6, 0.6000000000000001, 1],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 0.016318748060901066, 0.0061195305228378995],
#  [None, 0.034999999999999996, 0.016274706739090112, 0.006103015027158792],
#  [None, 0.045, 0.016238659569797965, 0.006089497338674238],
#  [None, 0.05499999999999999, 0.016208926055333847, 0.006078347270750193],
#  [None, 0.06499999999999999, 0.016184212845331437, 0.006069079816999289],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 74.2, 89.7, 0.20889],
#  [None, 'LCC', 2.666, 1, -0.6249],
#  [None, '가치', 27.8, 89.7, 2.22661],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-07토목02 기능성 시멘트 적용 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '1종보통 시멘트', None, '저발열 시멘트', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 17, 8, 136, 9, 153],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['시공성', 18, 8, 144, 9, 162],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['품질관리성', 14, 9, 126, 9, 126],
#  ['안정성', 21, 7, 147, 9, 189],
#  ['총 가중값', None, 823, None, 900, None],
#  ['LCC', '백만원', 616.1, None, 523.4, None],
#  ['성능점수 (P)', None, 82.3, None, 90, None],
#  ['상대 LCC (C)', None, 1.177, None, 1, None],
#  ['가치평가 (V=P/C)', None, 69.9, None, 90, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 422, 358.5, 63.5],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 194.1, 164.9, 29.19999999999999],
#  [None, '초기투자비', 616.1, 523.4, 92.70000000000005],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 616.1, 523.4, 92.70000000000005],
#  [None, '유지관리비', 0, 0, 0],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 616.1, 523.4, 92.70000000000005],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 6.1610000000000005, 5.234],
#  [None, 0.034999999999999996, 6.1610000000000005, 5.234],
#  [None, 0.045, 6.1610000000000005, 5.234],
#  [None, 0.05499999999999999, 6.1610000000000005, 5.234],
#  [None, 0.06499999999999999, 6.1610000000000005, 5.234],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 82.3, 90, 0.09356],
#  [None, 'LCC', 1.177, 1, -0.15038],
#  [None, '가치', 69.9, 90, 0.28755],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-08토목03 부력방지용 앵커 0904.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '부력저항키', None, '부력저항키+부력방지용 앵커', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 17, 8, 136, 9, 153],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['시공성', 18, 9, 162, 9, 162],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['품질관리성', 14, 9, 126, 9, 126],
#  ['안정성', 21, 6, 126, 10, 210],
#  ['총 가중값', None, 820, None, 921, None],
#  ['LCC', '백만원', 226.89999999999998, None, 247.5, None],
#  ['성능점수 (P)', None, 82, None, 92.1, None],
#  ['상대 LCC (C)', None, 0.916, None, 1, None],
#  ['가치평가 (V=P/C)', None, 89.5, None, 92.1, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 73.2, 141.4, -68.2],
#  [None, '관급자재비', 120, 41.1, 78.9],
#  [None, '제잡비', 33.7, 65, -31.299999999999997],
#  [None, '초기투자비', 226.89999999999998, 247.5, -20.600000000000023],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 226.89999999999998, 247.5, -20.600000000000023],
#  [None, '유지관리비', 0, 0, 0],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 226.89999999999998, 247.5, -20.600000000000023],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 2.2689999999999997, 2.475],
#  [None, 0.034999999999999996, 2.2689999999999997, 2.475],
#  [None, 0.045, 2.2689999999999997, 2.475],
#  [None, 0.05499999999999999, 2.2689999999999997, 2.475],
#  [None, 0.06499999999999999, 2.2689999999999997, 2.475],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 82, 92.1, 0.12317],
#  [None, 'LCC', 0.916, 1, 0.0917],
#  [None, '가치', 89.5, 92.1, 0.02905],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-09토목04 굴착공법 및 가시설계획 0917.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '시트파일+강관버팀보', None, '시트파일+어스앵커', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['적용성', 17, 8, 136, 9, 153],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['시공성', 18, 7, 126, 9, 162],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['품질관리성', 14, 8, 112, 9, 126],
#  ['안정성', 21, 7, 147, 9, 189],
#  ['총 가중값', None, 761, None, 900, None],
#  ['LCC', '백만원', 7603.7, None, 3677.7, None],
#  ['성능점수 (P)', None, 76.1, None, 90, None],
#  ['상대 LCC (C)', None, 2.067, None, 1, None],
#  ['가치평가 (V=P/C)', None, 36.8, None, 90, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 5208, 2519, 2689],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 2395.7, 1158.7, 1236.9999999999998],
#  [None, '초기투자비', 7603.7, 3677.7, 3926],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 7603.7, 3677.7, 3926],
#  [None, '유지관리비', 0, 0, 0],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 7603.7, 3677.7, 3926],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 76.03699999999999, 36.777],
#  [None, 0.034999999999999996, 76.03699999999999, 36.777],
#  [None, 0.045, 76.03699999999999, 36.777],
#  [None, 0.05499999999999999, 76.03699999999999, 36.777],
#  [None, 0.06499999999999999, 76.03699999999999, 36.777],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 76.1, 90, 0.18265],
#  [None, 'LCC', 2.067, 1, -0.5162],
#  [None, '가치', 36.8, 90, 1.44565],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-10토목05 외기노출부 방수공사 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '일체형 복합방수', None, '우레탄 도막방수', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['기능성', 21, 8, 168, 10, 210],
#  ['적용성', 15, 7, 105, 9, 135],
#  ['내구성', 15, 9, 135, 9, 135],
#  ['시공성', 15, 7, 105, 10, 150],
#  ['유지관리성', 14, 9, 126, 9, 126],
#  ['친환경성', 20, 9, 180, 8, 160],
#  ['총 가중값', None, 819, None, 916, None],
#  ['LCC', '백만원', 61.5, None, 39.2, None],
#  ['성능점수 (P)', None, 81.9, None, 91.6, None],
#  ['상대 LCC (C)', None, 1.568, None, 1, None],
#  ['가치평가 (V=P/C)', None, 52.2, None, 91.6, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 25.7, 13.7, 12],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 11.3, 6, 5.300000000000001],
#  [None, '초기투자비', 37, 19.7, 17.3],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 37, 19.7, 17.3],
#  [None, '유지관리비', 24.5, 19.5, 5],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 61.5, 39.2, 22.299999999999997],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 0.7291162559302998, 0.49052423196868405],
#  [None, 0.034999999999999996, 0.6661384375596195, 0.4353634103597585],
#  [None, 0.045, 0.6152089873460513, 0.39209547973040126],
#  [None, 0.05499999999999999, 0.573876479553817, 0.3578863623305897],
#  [None, 0.06499999999999999, 0.5402127969856412, 0.3306291336156045],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.9, 91.6, 0.11843],
#  [None, 'LCC', 1.568, 1, -0.36224],
#  [None, '가치', 52.2, 91.6, 0.75478],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-11토목06 운영실 휴게가든 0904.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '무창 계획', None, '휴게가든 계획', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['기능성', 21, 6, 126, 10, 210],
#  ['적용성', 15, 7, 105, 9, 135],
#  ['내구성', 15, 9, 135, 9, 135],
#  ['시공성', 15, 9, 135, 8, 120],
#  ['유지관리성', 14, 9, 126, 9, 126],
#  ['친환경성', 20, 6, 120, 10, 200],
#  ['총 가중값', None, 747, None, 926, None],
#  ['LCC', '백만원', 213.1, None, 258, None],
#  ['성능점수 (P)', None, 74.7, None, 92.6, None],
#  ['상대 LCC (C)', None, 0.825, None, 1, None],
#  ['가치평가 (V=P/C)', None, 90.5, None, 92.6, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 72, 102.8, -30.799999999999997],
#  [None, '관급자재비', 109.4, 110, -0.5999999999999943],
#  [None, '제잡비', 31.7, 45.2, -13.500000000000004],
#  [None, '초기투자비', 213.1, 258, -44.900000000000006],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 213.1, 258, -44.900000000000006],
#  [None, '유지관리비', 0, 0, 0],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 213.1, 258, -44.900000000000006],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 2.131, 2.58],
#  [None, 0.034999999999999996, 2.131, 2.58],
#  [None, 0.045, 2.131, 2.58],
#  [None, 0.05499999999999999, 2.131, 2.58],
#  [None, 0.06499999999999999, 2.131, 2.58],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 74.7, 92.6, 0.23962],
#  [None, 'LCC', 0.825, 1, 0.21212],
#  [None, '가치', 90.5, 92.6, 0.0232],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-12토목07 엘리베이터, 방풍실 계획 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '피난계단실 4개소', None, '3개소+엘리베이터, 방풍실', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['기능성', 21, 7, 147, 10, 210],
#  ['적용성', 15, 9, 135, 9, 135],
#  ['내구성', 15, 9, 135, 9, 135],
#  ['시공성', 15, 9, 135, 8, 120],
#  ['유지관리성', 14, 8, 112, 9, 126],
#  ['친환경성', 20, 9, 180, 9, 180],
#  ['총 가중값', None, 844, None, 906, None],
#  ['LCC', '백만원', 222.9, None, 227.5, None],
#  ['성능점수 (P)', None, 84.4, None, 90.6, None],
#  ['상대 LCC (C)', None, 0.979, None, 1, None],
#  ['가치평가 (V=P/C)', None, 86.2, None, 90.6, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 144, 147, -3],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 63.4, 64.7, -1.3000000000000043],
#  [None, '초기투자비', 207.4, 211.7, -4.299999999999983],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 207.4, 211.7, -4.299999999999983],
#  [None, '유지관리비', 15.5, 15.8, -0.3000000000000007],
#  [None, '잔존가치비', 0, 0, 0],
#  [None, '생애주기비', 222.9, 227.5, -4.599999999999994],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 2.2805885869715015, 2.3278717640398594],
#  [None, 0.034999999999999996, 2.252044305272779, 2.298735677079302],
#  [None, 0.045, 2.2286812336753057, 2.2748882216444657],
#  [None, 0.05499999999999999, 2.2094101996132487, 2.2552176434817968],
#  [None, 0.06499999999999999, 2.1933929503804364, 2.2388683104895772],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 84.4, 90.6, 0.07345],
#  [None, 'LCC', 0.979, 1, 0.02145],
#  [None, '가치', 86.2, 90.6, 0.05104],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-13기계01 스크린 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '로타리 제진기', None, '더블체인식 자동바 스크린', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 9, 126, 9, 126],
#  ['안정성', 22, 8, 176, 10, 220],
#  ['효율성', 19, 7, 133, 10, 190],
#  ['설치용이성', 15, 8, 120, 9, 135],
#  ['총 가중값', None, 795, None, 941, None],
#  ['LCC', '백만원', 274.4, None, 243.5, None],
#  ['성능점수 (P)', None, 79.5, None, 94.1, None],
#  ['상대 LCC (C)', None, 1.126, None, 1, None],
#  ['가치평가 (V=P/C)', None, 70.6, None, 94.1, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0, 0],
#  [None, '관급자재비', 158, 138, 20],
#  [None, '제잡비', 0, 0, 0],
#  [None, '초기투자비', 158, 138, 20],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 158, 138, 20],
#  [None, '유지관리비', 155, 139.2, 15.800000000000011],
#  [None, '잔존가치비', -38.6, -33.7, -4.899999999999999],
#  [None, '생애주기비', 274.4, 243.5, 30.899999999999977],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 3.1741851213740735, 2.82282435615284],
#  [None, 0.034999999999999996, 2.9394018477950152, 2.6107919207149677],
#  [None, 0.045, 2.743781313838578, 2.4342298136371703],
#  [None, 0.05499999999999999, 2.5801803250480844, 2.286633140759378],
#  [None, 0.06499999999999999, 2.442864922212243, 2.16278911644668],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 79.5, 94.1, 0.18364],
#  [None, 'LCC', 1.126, 1, -0.1119],
#  [None, '가치', 70.6, 94.1, 0.33286],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-14기계02 유량조정조 이중수문 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '비금속 수문', None, '양방향 차수 수문', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 9, 126, 9, 126],
#  ['안정성', 22, 8, 176, 10, 220],
#  ['효율성', 19, 8, 152, 10, 190],
#  ['설치용이성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 859, None, 941, None],
#  ['LCC', '백만원', 202, None, 99.69999999999999, None],
#  ['성능점수 (P)', None, 85.9, None, 94.1, None],
#  ['상대 LCC (C)', None, 2.026, None, 1, None],
#  ['가치평가 (V=P/C)', None, 42.4, None, 94.1, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 78.7, 3.5, 75.2],
#  [None, '관급자재비', 27.4, 59.8, -32.4],
#  [None, '제잡비', 24.4, 1.1, 23.299999999999997],
#  [None, '초기투자비', 130.5, 64.39999999999999, 66.10000000000001],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 130.5, 64.39999999999999, 66.10000000000001],
#  [None, '유지관리비', 103.4, 51, 52.400000000000006],
#  [None, '잔존가치비', -31.9, -15.7, -16.2],
#  [None, '생애주기비', 202, 99.69999999999999, 102.30000000000001],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 2.2926289930685484, 1.1313816640123715],
#  [None, 0.034999999999999996, 2.1441797741973097, 1.0581239651977528],
#  [None, 0.045, 2.0198235388141867, 0.9967558306485335],
#  [None, 0.05499999999999999, 1.9153953774838066, 0.9452219334096332],
#  [None, 0.06499999999999999, 1.8274946326203005, 0.9018440945651136],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 85.9, 94.1, 0.09545],
#  [None, 'LCC', 2.026, 1, -0.50641],
#  [None, '가치', 42.4, 94.1, 1.21933],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-15기계03 유입펌프 구성 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '유입펌프', None, '유입펌프+조절펌프', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 9, 135, 8, 120],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 7, 98, 9, 126],
#  ['안정성', 22, 8, 176, 10, 220],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 9, 135, 8, 120],
#  ['총 가중값', None, 812, None, 892, None],
#  ['LCC', '백만원', 1300.4, None, 1124.7, None],
#  ['성능점수 (P)', None, 81.2, None, 89.2, None],
#  ['상대 LCC (C)', None, 1.156, None, 1, None],
#  ['가치평가 (V=P/C)', None, 70.2, None, 89.2, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 12.5, 14.5, -2],
#  [None, '관급자재비', 136, 116, 20],
#  [None, '제잡비', 3.9, 4.5, -0.6000000000000001],
#  [None, '초기투자비', 152.4, 135, 17.400000000000006],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 152.4, 135, 17.400000000000006],
#  [None, '유지관리비', 1185.3, 1022.7, 162.5999999999999],
#  [None, '잔존가치비', -37.3, -33, -4.299999999999997],
#  [None, '생애주기비', 1300.4, 1124.7, 175.70000000000005],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 16.902343461943502, 14.607917501935917],
#  [None, 0.034999999999999996, 14.761532893403068, 12.761911118656771],
#  [None, 0.045, 13.004429423451015, 11.246657870185267],
#  [None, 0.05499999999999999, 11.551748999185882, 9.99384821993655],
#  [None, 0.06499999999999999, 10.342171338396872, 8.950642544360953],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.2, 89.2, 0.09852],
#  [None, 'LCC', 1.156, 1, -0.13494],
#  [None, '가치', 70.2, 89.2, 0.27065],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-16기계04 송풍기실 위치 0915.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '기존처리장', None, '증설처리장', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 8, 120, 9, 135],
#  ['에너지절감', 14, 7, 98, 9, 126],
#  ['안정성', 22, 7, 154, 10, 220],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 7, 105, 9, 135],
#  ['총 가중값', None, 715, None, 922, None],
#  ['LCC', '백만원', 4217.400000000001, None, 3243.6000000000004, None],
#  ['성능점수 (P)', None, 71.5, None, 92.2, None],
#  ['상대 LCC (C)', None, 1.3, None, 1, None],
#  ['가치평가 (V=P/C)', None, 55, None, 92.2, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 361.8, 239.6, 122.20000000000002],
#  [None, '관급자재비', 175, 118.4, 56.599999999999994],
#  [None, '제잡비', 112.2, 74.3, 37.900000000000006],
#  [None, '초기투자비', 649, 432.3, 216.7],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 649, 432.3, 216.7],
#  [None, '유지관리비', 3727.1, 2917, 810.0999999999999],
#  [None, '잔존가치비', -158.7, -105.7, -52.999999999999986],
#  [None, '생애주기비', 4217.400000000001, 3243.6000000000004, 973.8000000000002],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 54.31311453023464, 41.979610009959146],
#  [None, 0.034999999999999996, 47.64578688375388, 36.73689305318108],
#  [None, 0.045, 42.17449076558663, 32.43635676880882],
#  [None, 0.05499999999999999, 37.652276329487435, 28.882920607538946],
#  [None, 0.06499999999999999, 33.888114199836906, 25.925799231751153],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 71.5, 92.2, 0.28951],
#  [None, 'LCC', 1.3, 1, -0.23076],
#  [None, '가치', 55, 92.2, 0.67636],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-17기계05 호기조 산기장치 0915.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '멤브레인 디스크형', None, '초미세기포 판형', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 7, 98, 9, 126],
#  ['안정성', 22, 7, 154, 9, 198],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 8, 120, 9, 135],
#  ['총 가중값', None, 775, None, 900, None],
#  ['LCC', '백만원', 3706.8, None, 2296, None],
#  ['성능점수 (P)', None, 77.5, None, 90, None],
#  ['상대 LCC (C)', None, 1.614, None, 1, None],
#  ['가치평가 (V=P/C)', None, 48, None, 90, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 9.4, 4.4, 5],
#  [None, '관급자재비', 445.6, 279.7, 165.90000000000003],
#  [None, '제잡비', 2.9, 1.4, 1.5],
#  [None, '초기투자비', 457.9, 285.49999999999994, 172.40000000000003],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 457.9, 285.49999999999994, 172.40000000000003],
#  [None, '유지관리비', 3328.9, 2080.3, 1248.6],
#  [None, '잔존가치비', -80, -69.8, -10.200000000000003],
#  [None, '생애주기비', 3706.8, 2296, 1410.8000000000002],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 48.090275934228195, 29.778414904784448],
#  [None, 0.034999999999999996, 42.04108317997715, 26.032186502130756],
#  [None, 0.045, 37.068776992128974, 22.959712994054442],
#  [None, 0.05499999999999999, 32.95277109656394, 20.421328979469383],
#  [None, 0.06499999999999999, 29.521929604321507, 18.30911754898924],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 77.5, 90, 0.16129],
#  [None, 'LCC', 1.614, 1, -0.38042],
#  [None, '가치', 48, 90, 0.875],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-18기계06 분리막 미세협착물 세척 및 이송 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '2중세척+개별반출', None, '유입수전류압+약품세척+통합반출', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 9, 135, 8, 120],
#  ['에너지절감', 14, 7, 98, 9, 126],
#  ['안정성', 22, 9, 198, 9, 198],
#  ['효율성', 19, 7, 133, 10, 190],
#  ['설치용이성', 15, 8, 120, 9, 135],
#  ['총 가중값', None, 789, None, 904, None],
#  ['LCC', '백만원', 2256.3, None, 1439.1999999999998, None],
#  ['성능점수 (P)', None, 78.9, None, 90.4, None],
#  ['상대 LCC (C)', None, 1.567, None, 1, None],
#  ['가치평가 (V=P/C)', None, 50.4, None, 90.4, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0, 0],
#  [None, '관급자재비', 1186, 662, 524],
#  [None, '제잡비', 0, 0, 0],
#  [None, '초기투자비', 1186, 662, 524],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 1186, 662, 524],
#  [None, '유지관리비', 1360.3, 939.1, 421.19999999999993],
#  [None, '잔존가치비', -290, -161.9, -128.1],
#  [None, '생애주기비', 2256.3, 1439.1999999999998, 817.1000000000004],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 26.45362795100038, 17.1682888869788],
#  [None, 0.034999999999999996, 24.32827495231004, 15.65001817804027],
#  [None, 0.045, 22.56277887963261, 14.39286468190623],
#  [None, 0.05499999999999999, 21.08966975357929, 13.34650201138173],
#  [None, 0.06499999999999999, 19.85524668086444, 12.471207358473821],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 78.9, 90.4, 0.14575],
#  [None, 'LCC', 1.567, 1, -0.36183],
#  [None, '가치', 50.4, 90.4, 0.79365],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-19기계07 처리수 이송펌프 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '수중원심펌프', None, '편흡입 볼류트펌프', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 9, 135, 8, 120],
#  ['에너지절감', 14, 7, 98, 9, 126],
#  ['안정성', 22, 7, 154, 10, 220],
#  ['효율성', 19, 7, 133, 10, 190],
#  ['설치용이성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 760, None, 926, None],
#  ['LCC', '백만원', 1094.4999999999998, None, 822.7, None],
#  ['성능점수 (P)', None, 76, None, 92.6, None],
#  ['상대 LCC (C)', None, 1.33, None, 1, None],
#  ['가치평가 (V=P/C)', None, 57.1, None, 92.6, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 7, 4.5, 2.5],
#  [None, '관급자재비', 80.4, 29.3, 51.10000000000001],
#  [None, '제잡비', 2.2, 1.4, 0.8000000000000003],
#  [None, '초기투자비', 89.60000000000001, 35.199999999999996, 54.40000000000001],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 89.60000000000001, 35.199999999999996, 54.40000000000001],
#  [None, '유지관리비', 1026.8, 796.1, 230.69999999999993],
#  [None, '잔존가치비', -21.9, -8.6, -13.299999999999999],
#  [None, '생애주기비', 1094.4999999999998, 822.7, 271.7999999999997],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 14.344121849128321, 10.878098157042343],
#  [None, 0.034999999999999996, 12.476598286373386, 9.420476636123869],
#  [None, 0.045, 10.94518781769211, 8.226665543226453],
#  [None, 0.05499999999999999, 9.68004386984307, 7.24145045040627],
#  [None, 0.06499999999999999, 8.627233672654587, 6.422284377252941],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 76, 92.6, 0.21842],
#  [None, 'LCC', 1.33, 1, -0.24812],
#  [None, '가치', 57.1, 92.6, 0.62171],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-20기계08 농축기 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '무약주식', None, '약주식+폴리머', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 8, 120, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 9, 126, 9, 126],
#  ['안정성', 22, 7, 154, 10, 220],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 803, None, 922, None],
#  ['LCC', '백만원', 973.8999999999999, None, 901.5999999999999, None],
#  ['성능점수 (P)', None, 80.3, None, 92.2, None],
#  ['상대 LCC (C)', None, 1.08, None, 1, None],
#  ['가치평가 (V=P/C)', None, 74.4, None, 92.2, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0.5, -0.5],
#  [None, '관급자재비', 424, 393.9, 30.100000000000023],
#  [None, '제잡비', 0, 0.2, -0.2],
#  [None, '초기투자비', 424, 394.59999999999997, 29.400000000000034],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 424, 394.59999999999997, 29.400000000000034],
#  [None, '유지관리비', 653.6, 603.5, 50.10000000000002],
#  [None, '잔존가치비', -103.7, -96.5, -7.200000000000003],
#  [None, '생애주기비', 973.8999999999999, 901.5999999999999, 72.29999999999995],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 11.69218178343555, 10.81708989004664],
#  [None, 0.034999999999999996, 10.623563918234126, 9.831462243950078],
#  [None, 0.045, 9.739647327205248, 9.016114605886468],
#  [None, 0.05499999999999999, 9.004528418552384, 8.33797224539741],
#  [None, 0.06499999999999999, 8.389940585704664, 7.770989700231422],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 80.3, 92.2, 0.14819],
#  [None, 'LCC', 1.08, 1, -0.07407],
#  [None, '가치', 74.4, 92.2, 0.23924],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-21기계09 탈수 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '1m 상승 설치', None, '탈리액배관 이중화, 에어+워터플러싱', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 8, 120, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 9, 126, 9, 126],
#  ['안정성', 22, 8, 176, 9, 198],
#  ['효율성', 19, 8, 152, 10, 190],
#  ['설치용이성', 15, 7, 105, 10, 150],
#  ['총 가중값', None, 814, None, 934, None],
#  ['LCC', '백만원', 1064.2, None, 1151, None],
#  ['성능점수 (P)', None, 81.4, None, 93.4, None],
#  ['상대 LCC (C)', None, 0.924, None, 1, None],
#  ['가치평가 (V=P/C)', None, 88.1, None, 93.4, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 47.7, -47.7],
#  [None, '관급자재비', 490, 450.8, 39.19999999999999],
#  [None, '제잡비', 0, 14.8, -14.8],
#  [None, '초기투자비', 490, 513.3, -23.299999999999955],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 490, 513.3, -23.299999999999955],
#  [None, '유지관리비', 694, 763.2, -69.20000000000005],
#  [None, '잔존가치비', -119.8, -125.5, 5.700000000000003],
#  [None, '생애주기비', 1064.2, 1151, -86.79999999999995],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 12.692298278215091, 13.778973199112583],
#  [None, 0.034999999999999996, 11.570623308053225, 12.537205693667968],
#  [None, 0.045, 10.641837492970913, 11.509616576526223],
#  [None, 0.05499999999999999, 9.868771099038192, 10.654721436318955],
#  [None, 0.06499999999999999, 9.222084322065307, 9.939824932111485],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.4, 93.4, 0.14742],
#  [None, 'LCC', 0.924, 1, 0.08225],
#  [None, '가치', 88.1, 93.4, 0.06015],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-22기계10 탈취기 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '바이오필터', None, '3단약액세정+활성탄+약품분무', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 9, 135, 8, 120],
#  ['친환경성', 15, 7, 105, 10, 150],
#  ['에너지절감', 14, 8, 112, 9, 126],
#  ['안정성', 22, 7, 154, 10, 220],
#  ['효율성', 19, 6, 114, 10, 190],
#  ['설치용이성', 15, 9, 135, 8, 120],
#  ['총 가중값', None, 755, None, 926, None],
#  ['LCC', '백만원', 2335.2, None, 2697.2, None],
#  ['성능점수 (P)', None, 75.5, None, 92.6, None],
#  ['상대 LCC (C)', None, 0.865, None, 1, None],
#  ['가치평가 (V=P/C)', None, 87.3, None, 92.6, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0, 0],
#  [None, '관급자재비', 944, 1552.8, -608.8],
#  [None, '제잡비', 0, 0, 0],
#  [None, '초기투자비', 944, 1552.8, -608.8],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 944, 1552.8, -608.8],
#  [None, '유지관리비', 1622, 1524.1, 97.90000000000009],
#  [None, '잔존가치비', -230.8, -379.7, 148.89999999999998],
#  [None, '생애주기비', 2335.2, 2697.2, -362],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 28.25837584894365, 31.204235311620906],
#  [None, 0.034999999999999996, 25.5715228773536, 28.89560146354189],
#  [None, 0.045, 23.351737553356898, 26.97207442877475],
#  [None, 0.05499999999999999, 21.507343875029008, 25.363405444473106],
#  [None, 0.06499999999999999, 19.966373492398375, 24.013206217781622],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 75.5, 92.6, 0.22649],
#  [None, 'LCC', 0.865, 1, 0.15606],
#  [None, '가치', 87.3, 92.6, 0.06071],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-23기계11 탈취기실 위치 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '기존처리장', None, '증설처리장', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 8, 120, 9, 135],
#  ['친환경성', 15, 8, 120, 9, 135],
#  ['에너지절감', 14, 7, 98, 9, 126],
#  ['안정성', 22, 7, 154, 10, 220],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 7, 105, 10, 150],
#  ['총 가중값', None, 730, None, 937, None],
#  ['LCC', '백만원', 3495.5, None, 3295.4, None],
#  ['성능점수 (P)', None, 73, None, 93.7, None],
#  ['상대 LCC (C)', None, 1.06, None, 1, None],
#  ['가치평가 (V=P/C)', None, 68.9, None, 93.7, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0, 0],
#  [None, '관급자재비', 250, 964, -714],
#  [None, '제잡비', 0, 0, 0],
#  [None, '초기투자비', 250, 964, -714],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 250, 964, -714],
#  [None, '유지관리비', 3306.6, 2567.1, 739.5],
#  [None, '잔존가치비', -61.1, -235.7, 174.6],
#  [None, '생애주기비', 3495.5, 3295.4, 200.0999999999999],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 45.90894449762889, 41.02098923550004],
#  [None, 0.034999999999999996, 39.8881768549877, 36.59652645775489],
#  [None, 0.045, 34.95480271870244, 32.954096052566534],
#  [None, 0.05499999999999999, 30.881958510842175, 29.93594933887932],
#  [None, 0.06499999999999999, 27.494670676488898, 27.419236963256676],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 73, 93.7, 0.28356],
#  [None, 'LCC', 1.06, 1, -0.0566],
#  [None, '가치', 68.9, 93.7, 0.35994],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-24기계12 재이용계획 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '소포수 재이용수 분리공급', None, '소포수 재이용수 통합 분리공급', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 8, 120, 9, 135],
#  ['에너지절감', 14, 9, 126, 9, 126],
#  ['안정성', 22, 7, 154, 9, 198],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 8, 120, 9, 135],
#  ['총 가중값', None, 758, None, 900, None],
#  ['LCC', '백만원', 521.6999999999999, None, 420.6, None],
#  ['성능점수 (P)', None, 75.8, None, 90, None],
#  ['상대 LCC (C)', None, 1.24, None, 1, None],
#  ['가치평가 (V=P/C)', None, 61.1, None, 90, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 6.6, 2.1, 4.5],
#  [None, '관급자재비', 43.2, 14.5, 28.700000000000003],
#  [None, '제잡비', 2, 0.7, 1.3],
#  [None, '초기투자비', 51.800000000000004, 17.3, 34.5],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 51.800000000000004, 17.3, 34.5],
#  [None, '유지관리비', 482.6, 407.5, 75.10000000000002],
#  [None, '잔존가치비', -12.7, -4.2, -8.5],
#  [None, '생애주기비', 521.6999999999999, 420.6, 101.09999999999991],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 6.806863508592662, 5.563270066783908],
#  [None, 0.034999999999999996, 5.9331743843043965, 4.816908781911091],
#  [None, 0.045, 5.216940426783985, 4.205644949340628],
#  [None, 0.05499999999999999, 4.625419230983886, 3.7011982274181783],
#  [None, 0.06499999999999999, 4.133333975564349, 3.2817775199558827],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 75.8, 90, 0.18733],
#  [None, 'LCC', 1.24, 1, -0.19354],
#  [None, '가치', 61.1, 90, 0.47299],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-25기계13 방류펌프 용량 0907.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '12㎥/min x 2대', None, '8㎥/min x 2대', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 8, 120, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 7, 98, 10, 140],
#  ['안정성', 22, 9, 198, 9, 198],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 9, 135, 9, 135],
#  ['총 가중값', None, 819, None, 914, None],
#  ['LCC', '백만원', 4445.599999999999, None, 4176.8, None],
#  ['성능점수 (P)', None, 81.9, None, 91.4, None],
#  ['상대 LCC (C)', None, 1.064, None, 1, None],
#  ['가치평가 (V=P/C)', None, 77, None, 91.4, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 19.5, 8.3, 11.2],
#  [None, '관급자재비', 210, 130, 80],
#  [None, '제잡비', 6, 2.6, 3.4],
#  [None, '초기투자비', 235.5, 140.9, 94.6],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 235.5, 140.9, 94.6],
#  [None, '유지관리비', 4267.7, 4070.4, 197.29999999999973],
#  [None, '잔존가치비', -57.6, -34.5, -23.1],
#  [None, '생애주기비', 4445.599999999999, 4176.8, 268.7999999999993],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 58.64319142456181, 55.347671192947416],
#  [None, 0.034999999999999996, 50.844234275776735, 47.88203728285128],
#  [None, 0.045, 44.455755350323464, 41.76844645915623],
#  [None, 0.05499999999999999, 39.182873557087056, 36.723649341815516],
#  [None, 0.06499999999999999, 34.798289164564814, 32.5294397709701],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.9, 91.4, 0.11599],
#  [None, 'LCC', 1.064, 1, -0.06015],
#  [None, '가치', 77, 91.4, 0.18701],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-26기계14 급기팬룸 설치 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '1개소', None, '2개소', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 9, 135, 9, 135],
#  ['에너지절감', 14, 9, 126, 8, 112],
#  ['안정성', 22, 6, 132, 10, 220],
#  ['효율성', 19, 6, 114, 9, 171],
#  ['설치용이성', 15, 9, 135, 8, 120],
#  ['총 가중값', None, 747, None, 893, None],
#  ['LCC', '백만원', 39, None, 45.5, None],
#  ['성능점수 (P)', None, 74.7, None, 89.3, None],
#  ['상대 LCC (C)', None, 0.857, None, 1, None],
#  ['가치평가 (V=P/C)', None, 87.2, None, 89.3, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 18, 21, -3],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 7.2, 8.4, -1.2000000000000002],
#  [None, '초기투자비', 25.2, 29.4, -4.199999999999999],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 25.2, 29.4, -4.199999999999999],
#  [None, '유지관리비', 20, 23.3, -3.3000000000000007],
#  [None, '잔존가치비', -6.2, -7.2, 1],
#  [None, '생애주기비', 39, 45.5, -6.5],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 0.44271456417875416, 0.5165003248752131],
#  [None, 0.034999999999999996, 0.4140485081208598, 0.48305659280766977],
#  [None, 0.045, 0.39003489025377397, 0.45504070529606966],
#  [None, 0.05499999999999999, 0.3698694522037696, 0.4315143609043979],
#  [None, 0.06499999999999999, 0.35289551526460977, 0.411711434475378],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 74.7, 89.3, 0.19544],
#  [None, 'LCC', 0.857, 1, 0.16686],
#  [None, '가치', 87.2, 89.3, 0.02408],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-27기계15 별도 풍도설치 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '증설덕트 기존하수처리장 통과', None, '별도 풍도설치', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 7, 105, 9, 135],
#  ['친환경성', 15, 8, 120, 9, 135],
#  ['에너지절감', 14, 8, 112, 9, 126],
#  ['안정성', 22, 7, 154, 9, 198],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 7, 105, 10, 150],
#  ['총 가중값', None, 729, None, 915, None],
#  ['LCC', '백만원', 630.6, None, 466.4, None],
#  ['성능점수 (P)', None, 72.9, None, 91.5, None],
#  ['상대 LCC (C)', None, 1.352, None, 1, None],
#  ['가치평가 (V=P/C)', None, 53.9, None, 91.5, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 291, 310, -19],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 116.4, 124, -7.599999999999994],
#  [None, '초기투자비', 407.4, 434, -26.600000000000023],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 407.4, 434, -26.600000000000023],
#  [None, '유지관리비', 322.8, 32.4, 290.40000000000003],
#  [None, '잔존가치비', -99.6, 0, -99.6],
#  [None, '생애주기비', 630.6, 466.4, 164.20000000000005],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 7.157218787556526, 4.7723020575970665],
#  [None, 0.034999999999999996, 6.693784214620567, 4.7125710148909645],
#  [None, 0.045, 6.30556405910268, 4.66368204153849],
#  [None, 0.05499999999999999, 5.9795561439609415, 4.623355962546528],
#  [None, 0.06499999999999999, 5.705144163444524, 4.589838671480758],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 72.9, 91.5, 0.25514],
#  [None, 'LCC', 1.352, 1, -0.26035],
#  [None, '가치', 53.9, 91.5, 0.69758],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-28기계16 운영실 전열교환기 설치 0903.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '외기공급', None, '전열교환기 설치', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['유지관리성', 15, 9, 135, 9, 135],
#  ['친환경성', 15, 8, 120, 9, 135],
#  ['에너지절감', 14, 7, 98, 10, 140],
#  ['안정성', 22, 9, 198, 9, 198],
#  ['효율성', 19, 7, 133, 9, 171],
#  ['설치용이성', 15, 9, 135, 8, 120],
#  ['총 가중값', None, 819, None, 899, None],
#  ['LCC', '백만원', 59, None, 56.7, None],
#  ['성능점수 (P)', None, 81.9, None, 89.9, None],
#  ['상대 LCC (C)', None, 1.04, None, 1, None],
#  ['가치평가 (V=P/C)', None, 78.8, None, 89.9, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 4.5, 15, -10.5],
#  [None, '관급자재비', 0, 0, 0],
#  [None, '제잡비', 1.8, 6, -4.2],
#  [None, '초기투자비', 6.3, 21, -14.7],
#  ['2. 생애주기비', None, '원안', '금회제안', '절감액'],
#  [None, '초기투자비', 6.3, 21, -14.7],
#  [None, '유지관리비', 54.2, 39.6, 14.600000000000001],
#  [None, '잔존가치비', -1.5, -3.9, 2.4],
#  [None, '생애주기비', 59, 56.7, 2.299999999999997],
#  ['3. 민감도', None, '원안', '금회제안'],
#  [None, 0.024999999999999998, 0.7680965166531312, 0.688315101138217],
#  [None, 0.034999999999999996, 0.6700947764035712, 0.6220532565693668],
#  [None, 0.045, 0.5897440852717447, 0.5672585054373193],
#  [None, 0.05499999999999999, 0.5233773521769984, 0.5217320147049435],
#  [None, 0.06499999999999999, 0.46816287231223636, 0.4837185434051805],
#  ['4. 가치분석', None, '원안', '금회제안', '증감율'],
#  [None, '성능', 81.9, 89.9, 0.09768],
#  [None, 'LCC', 1.04, 1, -0.03846],
#  [None, '가치', 78.8, 89.9, 0.14086],
#  ['C:/Users/won-pc30/Desktop/VE\\제안-29전기01 VCB반 설치 0902.xlsx'],
#  ['평가항목', '가중치', '원안', None, '금회제안', None],
#  [None, None, '증설하수처리장\n 전원공급', None, '증설하수처리장+\n향후증설분 전원공급', None],
#  [None, None, '등급', '점수', '등급', '점수'],
#  ['안정성', 18, 5, 90, 10, 180],
#  ['내구성', 13, 9, 117, 9, 117],
#  ['시공성', 15, 9, 135, 9, 135],
#  ['신뢰성', 17, 4, 68, 10, 170],
#  ['유지관리성', 18, 9, 162, 9, 162],
#  ['효율성', 19, 3, 57, 10, 190],
#  ['총 가중값', None, 629, None, 954, None],
#  ['LCC', '백만원', 85.19999999999999, None, 127.7, None],
#  ['성능점수 (P)', None, 62.9, None, 95.4, None],
#  ['상대 LCC (C)', None, 0.667, None, 1, None],
#  ['가치평가 (V=P/C)', None, 94.3, None, 95.4, None],
#  ['1. 초기투자비', None, '원안', '금회제안', '절감액'],
#  [None, '직접공사비', 0, 0, 0],
#  [None, '관급자재비', 55, 82.5, -27.5],
#  [None, '제잡비', 0, 0, 0],
#  [None, '초기투자비', 55, 82.5, -27.5],
#  ...]

# %%
wb = openpyxl.Workbook() #워크북 생성
sheet1 = wb.active #활성시트를 만들어서 sheet1에 저장
sheet1.title = 'Sheet1' #시트의 제목 지정
# all_values 의 내용을 for문을 통해 기입
for row_num,row in enumerate(allData): #row 번호와 함께 row를 순차적으로 가져옴
    for col_num,cell_val in enumerate(row): #row 마다 cell 번호와 cell 내용을 함께 가져옴
        sheet1.cell(row=row_num+1, column=col_num+1).value = cell_val #행번호와 열번호를 지정하여 값을 기록, 엑셀은 1부터 시작
wb.save(filename="./test2.xlsx") #결과물 저장
