# %% [markdown]
# ## 엑셀로 저장된 거래정보를 더존 시스템에 수동으로 대량입력 하는 업무
# 최종 적용과 중간과정을 저장

# %%
#사용한 라이브러리
import pyautogui #키보드 마우스 제어
import openpyxl #엑셀파일 열기
import pyperclip #한글입력이 필요한 경우 엑셀의 데이터를 클립보드로 전송
import time #네트워크 지연 등에 대응

# %% [markdown]
# ### UI 위치에 대한 세팅
# 작업창을 놓은 위치에 따라서 인식해줘야 함

# %%
screenWidth,screenHeight = pyautogui.size() #해상도 지정
screenWidth,screenHeight #확인
# Out:
# (2560, 1440)

# %%
nex=pyautogui.position() 
nex
# Out:
# Point(x=258, y=345)

# %%
gubun=pyautogui.position()
gubun
# Out:
# Point(x=233, y=236)

# %%
dayClick=pyautogui.position()
dayClick
# Out:
# Point(x=155, y=616)

# %% [markdown]
# ### 엑셀 문서 파일 읽어서 입력 데이터 준비
# 데이터 확인

# %%
of = openpyxl.load_workbook("./arr411.xlsx") #엑셀 파일 열어서
sheet = of.active 
wb = openpyxl.Workbook() 
ws=wb.active
all_values = []
for row in sheet.rows:  #리스트로
    row_value = []
    for cell in row:
        row_value.append(cell.value)
    all_values.append(row_value)
print(all_values) ##확인
### 개인정보 가림처리한 문서
# Out:
# [['06', '31', '3', '103', '98000', '###', 12000000, '####'], ['06', '31', '4', '108', '00102', '###', 12000000, '####'], ['06', '31', '4', '103', '98000', '###', 3520500, '####'], ['06', '31', '3', '253', '00199', '###', 3520000, '####'], ['06', '31', '3', '831', '98000', '###', 500, '####'], ['06', '31', '4', '103', '98000', '###', 397890, '####'], ['06', '31', '3', '253', '00200', '###', 349918, '####'], ['06', '31', '3', '516', '00200', '###', 11760, '####'], ['06', '31', '4', '556', '00200', '###', 8, '####'], ['06', '31', '3', '253', '00199', '###', 36220, '####'], ['06', '31', '3', '816', '00199', '###', 36220, '####'], ['06', '31', '4', '253', '00199', '###', 36220, '####'], ['06', '31', '4', '103', '98000', '###', 30440, '####'], ['06', '31', '3', '815', 0, '###', 30440, '####'], ['06', '31', '3', '802', '00207', '###', 3100000, '####'], ['06', '31', '4', '254', '00168', '###', 96900, '####'], ['06', '31', '4', '254', '00167', '###', 135000, '####'], ['06', '31', '4', '254', 
# ...

# %%
#최종적으로 입력에 사용한 코드
of = openpyxl.load_workbook("../arr411.xlsx") #엑셀파일 열기
sheet = of.active 
wb = openpyxl.Workbook() 
ws=wb.active
all_values = []
for row in sheet.rows: #엑셀파일 리스트에 담기
    row_value = []
    for cell in row:
        row_value.append(cell.value)
    all_values.append(row_value)
pyautogui.click(gubun) #일력가능한 윈도우를 클릭
for i in all_values:   
    time.sleep(0.1)
    pyautogui.write(i[0]) #구분 코드입력은 pyautogui 의 기능으로 해결
    time.sleep(0.1)
    pyautogui.write(i[1])
    time.sleep(0.1)
    pyautogui.write(i[2])
    time.sleep(0.1)
    time.sleep(0.1)
    time.sleep(0.1)
    pyautogui.write(i[3])
    time.sleep(0.1)
    if i[4]!=0:
        pyautogui.write(i[4])
        time.sleep(0.1)   
        pyautogui.press('enter')
    if i[4]==0:
        pyautogui.press('right')
        time.sleep(0.1)
    if i[5]!=0:
        pyperclip.copy(i[5])
        pyautogui.hotkey("ctrl", "v")
        time.sleep(0.1)
        pyautogui.press('enter')
    if i[5]==0:
        pyautogui.press('right')
        time.sleep(0.1)
        time.sleep(0.1)
    time.sleep(0.1)
    pyperclip.copy(i[6]) #pyautogui 는 한글입력이 안되므로 클립보드로 보내서 데이터 입력
    pyautogui.hotkey("ctrl", "v") #pyautogui 는 한글입력이 안되므로 클립보드로 보내서 데이터 입력
    time.sleep(0.1)
    pyautogui.press('enter')
    time.sleep(0.1)
    pyautogui.press('right')
    pyperclip.copy(i[7])
    pyautogui.hotkey("ctrl", "v")
    time.sleep(0.1)
    if i[3]=='817' or i[3]=='816' or i[3]=='822' or i[3]=='815' or i[3]=='814': ##입력 시 오동작을 일으키는 항목 예외처리
        print(i[3])
        pyautogui.press('enter')
        time.sleep(0.1)
        pyautogui.press('down')
        time.sleep(0.1)
        print(i)
        break
    pyautogui.press('enter')
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-41e7fee772bc> in <module>
#      25         pyautogui.write(i[4])
#      26         time.sleep(0.1)
# ---> 27         pyautogui.press('enter')
#      28     if i[4]==0:
#      29         pyautogui.press('right')
#
# E:\anaconda3\lib\site-packages\pyautogui\__init__.py in press(keys, presses, interval, pause, logScreenshot, _pause)
#    1177         time.sleep(interval)
#    1178
# -> 1179     _autoPause(pause, _pause)
#    1180
#    1181 def typewrite(message, interval=0.0, pause=None, logScreenshot=None, _pause=True):
#
# E:\anaconda3\lib\site-packages\pyautogui\__init__.py in _autoPause(pause, _pause)
#     240     elif _pause:
#     241         assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 242         time.sleep(PAUSE)
#     243
#     244
#
# KeyboardInterrupt:

# %% [markdown]
# #### 1
# 1###### 6월 이순남 전력비 지급
#
#
#
# 07
# 01
#
# 363890

# %% [markdown]
# ## 중간과정 보존용

# %%
# pyperclip.copy 기능 테스트

pyautogui.click(dayClick)
pyperclip.copy('1')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('right')
pyperclip.copy('10')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('enter')
pyperclip.copy('4')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('enter')
pyperclip.copy('253')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('enter')
pyperclip.copy('00195')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('enter')
pyperclip.copy('아구랜드')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('enter')
pyperclip.copy('20195')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('right')
pyautogui.press('right')
pyperclip.copy('아구랜드')
pyautogui.hotkey("ctrl", "v")
pyautogui.press('right')

# %%
#한글입력 안되는 부분 pyautogui자체 해결 시도 
#그러나 중간에 영문입력이 필요할 경우 번거로움
pyautogui.click(gubun)

pyautogui.write("4138\nvkwntl\n36000\n\nvkwnwpdlf-wlwn\n",interval=0.1)
pyautogui.write("3824\nehdqkdrjstjfrlrP\n1990\n\ndkzmflfdnsqks\n",interval=0.1)
pyautogui.write("4138\nehdqkdrjstjfrlrP\n1990\n\ndkzmflfdnsqks\n",interval=0.1)
pyautogui.write("3812\n\n1600\n\nehfhxhdgodfy\n",interval=0.2)
pyautogui.write("4138\n\n1600\n\nehfhxhdgodfy\n",interval=0.2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-4f6783d4a122> in <module>
#       5 pyautogui.write("073812\neldhqlfrkdskarhksfleks\n4000\n\n\n",interval=0.1)
#       6 pyautogui.write("08425300195\n \n28000\n\n\n",interval=0.1)
# ----> 7 pyautogui.write("083812\n(wn)thdcnrkakrhf vksrywlwja\n28000\n\n\n",interval=0.1)
#       8 pyautogui.write("09425300195\n \n49000\n\n\n",interval=0.1)
#       9 pyautogui.write("093812\nshdguqdbxhd gkskfh wndbth\n49000\n\n\n",interval=0.1)
#
# d:\ProgramData\Anaconda3\lib\site-packages\pyautogui\__init__.py in typewrite(message, interval, pause, logScreenshot, _pause)
#    1209             c = c.lower()
#    1210         press(c, _pause=False)
# -> 1211         time.sleep(interval)
#    1212         failSafeCheck()
#    1213
#
# KeyboardInterrupt:

# %% [markdown]
# #

# %% [raw]
# pyautogui.click(gubun)
# pyautogui.write("3831\ntkeksqjqdlsrudrlehdhrdhlrhkdrhguqghl\n75900\n\nGSrhdmqwndbth\n",interval=0.1)

# %%
#한글 영타 변환기를 이용하여 시험 작업

time.sleep(1)
pyautogui.click(gubun)
time.sleep(1)

pyautogui.write("425300195\n \n6300\n\nNHzkem(5531810226434883)(xlajslqjqdlsxortl)\n",interval=0.1)
pyautogui.write("3812\nxlajslqjqdlsxortl\n6300\n\nrhdbswls ryxhdql\n",interval=0.1)
pyautogui.write("410398000\n \n216100\n\n(rldjq)47501811204011-NHzkem 4dnjfrufwp\n",interval=0.1)
pyautogui.write("325300195\n \n216100\n\n4dnjf shdguqzkem eormawlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n31900\n\nNHzkem(5531810226434883)(sbzhdkdkdnffptrkdskawja)\n",interval=0.1)
pyautogui.write("3811\nsbzhdkdkdnffptrkdskawja\n31900\n\nrmsfhwk wkrdjqqhr\n",interval=0.1)
pyautogui.write("425300195\n \n58000\n\nNHzkem(5531810226434883)(eoghkwkehdckwjdql(wn))\n",interval=0.1)
pyautogui.write("3822\neoghkwkehdckwjdql(wn)\n58000\n\nrhdbswls ckfidtnfl\n",interval=0.1)
pyautogui.write("310398000\n \n4000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n4000000\n\ndPdlfxhxkfTkdls aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n3225690\n\n(rldjq)47501811204011 rnrtp_dpfTmflwntlrghl\n",interval=0.1)
pyautogui.write("3261\nqnrktp\n3225690\n\n2019sus1rldPwjd qnrktp\n",interval=0.1)
pyautogui.write("425300195\n \n51000\n\nNHzkem(5531810226434883)((wn)Rksqn rnqksvhwja)\n",interval=0.1)
pyautogui.write("3811\n(wn)Rksqn rnqksvhwja\n51000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n6000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n6000000\n\ndPdlfxhxkfTkdls aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n30730\n\n(rldjq)47501811204011 tkdgktneh04\n",interval=0.1)
pyautogui.write("3815\n\n30730\n\nskadidwntl 4dnjf tnehfy(dpfTmfl)\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n4dnjf dlaeofy wlrmq(dpfTmfl)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n1320500\n\n(rldjq)47501811204011 tpanqjqdlsrkejr\n",interval=0.1)
pyautogui.write("325300164\n \n1320000\n\n18.19sus rlwkdfy dlqrma\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n1174800\n\n(rldjq)47501811204011 wntlrghltkdpaelzh\n",interval=0.1)
pyautogui.write("325100187\n \n1174800\n\ndhltkdaodlqrma wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n13758350\n\n(rldjq)47501811204011 rhdbswls\n",interval=0.1)
pyautogui.write("325300207\n \n13758350\n\n2018sus rhdbswls alwlrmq rmqdu\n",interval=0.1)
pyautogui.write("410398000\n \n27148175\n\n(rldjq)47501811204011 rlackwnd\n",interval=0.1)
pyautogui.write("3253\nrlackwnd\n27147675\n\n2019sus rlackwnd alwlrmq rmqdu\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n19720660\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("3253\ndlwodyd\n19720660\n\n2018sus dlwodyd alwlrmq rmqdu\n",interval=0.1)
pyautogui.write("310398000\n \n61000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n61000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n380940\n\n(rldjq)47501811204011 04dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n328566\n\n4dnjf dpfTmflwjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n11050\n\n4dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n6\n\n4dnjf dpfTmfl wjsfurql dnjseksdnl wjftk\n",interval=0.1)
pyautogui.write("325300199\n \n41330\n\n4dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n41330\n\n4dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n41330\n\n4dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("3802\ndlwodyd\n1000000\n\n4dnjfqns rmqdu(dlwodyd)\n",interval=0.1)
pyautogui.write("425400168\n \n29070\n\n4dnjfqns rjsrkdqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n33520\n\n4dnjfqns dusrmaqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400191\n \n5850\n\n4dnjfqns rhdydqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n2470\n\n4dnjfqns wkdrldydidfy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("4253\ndlwodyd\n929090\n\n4dnjf rmqdu alwlrmqqns(dlwodyd)\n",interval=0.1)
pyautogui.write("380200207\n \n3100000\n\n4dnjfqns rmqdu(rhdbswls)\n",interval=0.1)
pyautogui.write("425400168\n \n96900\n\n4dnjfqns rjsrkdqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n135000\n\n4dnjfqns dusrmaqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n19500\n\n4dnjfqns rhdydqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n8240\n\n4dnjfqns wkdrldydidfy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n4dnjfqns themrtp,wlqkdthemrtp\n",interval=0.1)
pyautogui.write("425300207\n \n2747030\n\n4dnjf rmqdu alwlrmqqns(rhdbswls)\n",interval=0.1)
pyautogui.write("425300195\n \n33000\n\nNHzkem(5531810226434883)(wntlrghltkskaans(tnvthrRkvp))\n",interval=0.1)
pyautogui.write("3811\nwntlrghltkskaans(tnvthrRkvp)\n33000\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300195\n \n15000\n\nNHzkem(5531810226434883)(rhdrhd(tpdhl)_tjdnfeorhddnjs)\n",interval=0.1)
pyautogui.write("3822\nrhdrhd(tpdhl)_tjdnfeorhddnjs\n15000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)(ehddnjsrjstjftksdjq wntlrghltk)\n",interval=0.1)
pyautogui.write("3822\nehddnjsrjstjftksdjq wntlrghltk\n3000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)(ehddnjsrjstjftksdjq wntlrghltk)\n",interval=0.1)
pyautogui.write("3822\nehddnjsrjstjftksdjq wntlrghltk\n3000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n6000\n\nNHzkem(5531810226434883)(ejzofht rlflswja)\n",interval=0.1)
pyautogui.write("3811\nejzofht rlflswja\n6000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n4410900\n\n(rldjq)47501811204011 dpaelzh2018susqns\n",interval=0.1)
pyautogui.write("410800187\n \n4410900\n\nwntlrghltk dpaelzh aocnf dlqrma\n",interval=0.1)
pyautogui.write("425300195\n \n31400\n\nNHzkem(5531810226434883)(rkdskaguseoclrhkdmldnjs)\n",interval=0.1)
pyautogui.write("3811\nrkdskaguseoclrhkdmldnjs\n31400\n\nrhdbswls eovy quddnjsclfy\n",interval=0.1)
pyautogui.write("425300195\n \n4700\n\nNHzkem(5531810226434883)(xlajsl qjqdlsxortl)\n",interval=0.1)
pyautogui.write("3812\nxlajsl qjqdlsxortl\n4700\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n10600\n\nNHzkem(5531810226434883)(xlajsl rodlsxortl dudtp)\n",interval=0.1)
pyautogui.write("3812\nxlajsl rodlsxortl dudtp\n10600\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n25500\n\nNHzkem(5531810226434883)((wn)tmxkqjrtmzjvlzhfldk)\n",interval=0.1)
pyautogui.write("3811\n(wn)tmxkqjrtmzjvlzhfldk\n25500\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300195\n \n12900\n\nNHzkem(5531810226434883)(BKRqjzjzld rkdskaNCwja)\n",interval=0.1)
pyautogui.write("3811\nBKRqjzjzld rkdskaNCwja\n12900\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n4830500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n4830000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)(gksdnflqhghwkrdjqwkd(godqhrgks qpdlzjfl&zk\n",interval=0.1)
pyautogui.write("3811\ngksdnflqhghwkrdjqwkd(godqhrgks qpdlzjfl&zkvp)\n12000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n5500\n\nNHzkem(5531810226434883)(gksrnrwjdqhxhdtls_tjchrncjd)\n",interval=0.1)
pyautogui.write("3822\ngksrnrwjdqhxhdtls_tjchrncjd\n5500\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("310398000\n \n4000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n4000000\n\ndPdlfxhxkfTkdls(wn) aocnfdlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011 SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\nrldjqdmsgod dlqcnfrma xhdwltntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP904\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n4dnjf Serp tkdydfy\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1899647\n\ngytjd CNCwkdql fltmfy 36ghlwnd 13ghl skqqn(wksdor:75,898,276)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n317674\n\ngytjd CNCwkdql fltmfy 36ghlwnd 13ghl skqqn/dlwkqldyd\n",interval=0.1)
pyautogui.write("410398000\n \n337040\n\n(rldjq)47501811204011 rnralsdusrma1904\n",interval=0.1)
pyautogui.write("325400167\n \n168520\n\n4dnjf rnralsdusrma(rmsfhwk qnekarma)\n",interval=0.1)
pyautogui.write("381700167\n \n168520\n\n4dnjf rnralsdusrma(ghltk qnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n273360\n\n(rldjq)47501811204011 rnralsrjsrkd1904\n",interval=0.1)
pyautogui.write("325400168\n \n136680\n\n4dnjf rjsrkdqhgjafy(rmsfhwk qnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n136680\n\n4dnjf rjsrkdqhgjafy(ghltk qnekarma)\n",interval=0.1)
pyautogui.write("425300195\n \n8600\n\nNHzkem(5531810226434883)(roffjflK)\n",interval=0.1)
pyautogui.write("3822\nroffjflK\n8600\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("310398000\n \n6000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n6000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n6600500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n6600000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n18000\n\nNHzkem(5531810226434883)((wn) vldpaqldpvmqmdlghfeldtm)\n",interval=0.1)
pyautogui.write("3811\n(wn) vldpaqldpvmqmdlghfeldtm\n18000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n13800\n\nNHzkem(5531810226434883)(rkdskaguseoclrhkdmldnjs)\n",interval=0.1)
pyautogui.write("3811\nrkdskaguseoclrhkdmldnjs\n13800\n\nrhdbswls eovy quddnjsclfy\n",interval=0.1)
pyautogui.write("410398000\n \n415200\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n415200\n\n5dnjf shdguqzkem eormawlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n50000\n\nNHzkem(5531810226434883)(shdguqdbxhd gkskfh wndbth)\n",interval=0.1)
pyautogui.write("3822\nshdguqdbxhd gkskfh wndbth\n50000\n\nrhdbswls eovy wndbeo\n",interval=0.1)
pyautogui.write("425300195\n \n9600\n\nNHzkem(5531810226434883)(wpfkspdlcj wntlrghltk)\n",interval=0.1)
pyautogui.write("3811\nwpfkspdlcj wntlrghltk\n9600\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)((wn)ehdtla)\n",interval=0.1)
pyautogui.write("3811\n(wn)ehdtla\n12000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n1000\n\nNHzkem(5531810226434883)(wldptmvkzm24(wn)qksvhwp2wnckwkd)\n",interval=0.1)
pyautogui.write("3822\nwldptmvkzm24(wn)qksvhwp2wnckwkd\n1000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n26000\n\nNHzkem(5531810226434883)(gksrkdclzls)\n",interval=0.1)
pyautogui.write("3811\ngksrkdclzls\n26000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n13700\n\nNHzkem(5531810226434883)(fhteptyvld(wn)fhtepakxm tjchwja clwmdos\n",interval=0.1)
pyautogui.write("3811\nfhteptyvld(wn)fhtepakxm tjchwja clwmdosehdn(\n13700\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n4000\n\nNHzkem(5531810226434883)(KCP-rufwp_vkzldzmffkdnem(wn))\n",interval=0.1)
pyautogui.write("3811\nKCP-rufwp_vkzldzmffkdnem(wn)\n4000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n19000\n\nNHzkem(5531810226434883)(aotehffhaks)\n",interval=0.1)
pyautogui.write("3811\naotehffhaks\n19000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n69130\n\nNHzkem(5531810226434883)(SKTdyrmaskqqn)\n",interval=0.1)
pyautogui.write("3814\nSKTdyrmaskqqn\n69130\n\nxhdtlsql-gosemvhs dyrma skqqn\n",interval=0.1)
pyautogui.write("310398000\n \n12000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n12000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n5dnjf dlaeofy wlrmq(dpfTmfl)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n397890\n\n(rldjq)47501811204011 05dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n349918\n\n5dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n11760\n\n5dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n8\n\n5dnjf dpfTmfl wjsfurql dnjseksdnlwjftk\n",interval=0.1)
pyautogui.write("325300199\n \n36220\n\n5dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n36220\n\n5dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n36220\n\n5dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("410398000\n \n30440\n\n(rldjq)47501811204011 tneh1905\n",interval=0.1)
pyautogui.write("3815\n\n30440\n\n5dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("380200207\n \n3100000\n\n5dnjfqns rmqdu(rhdbswls)\n",interval=0.1)
pyautogui.write("425400168\n \n96900\n\n5dnjfqns rjsrkdqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n135000\n\n5dnjfqns rnralsdusrmaqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400191\n \n19500\n\n5dnjfqns rhdydqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n8240\n\n5dnjfqns wkdrldydidqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n5dnjfqns rkqrmstpdhl\n",interval=0.1)
pyautogui.write("425300207\n \n2747030\n\n5dnjf rmqdu alwlrmqqns(rhdbswls)\n",interval=0.1)
pyautogui.write("3802\ndlwodyd\n1000000\n\n5dnjfqns rmqdu(dlwodyd)\n",interval=0.1)
pyautogui.write("425400168\n \n29070\n\n5dnjfqns rjsrkdqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n33520\n\n5dnjfqns rnralsdusrmaqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400191\n \n5850\n\n5dnjfqns rhdydqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n2470\n\n5dnjfqns wkdrldydidqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("4253\ndlwodyd\n929090\n\n5dnjfqns rmqdu alwlrmqqns(dlwodyd)\n",interval=0.1)
pyautogui.write("425300195\n \n15000\n\nNHzkem(5531810226434883)(rhdrhd(tpdhl)_tjdnfeorhddnjs)\n",interval=0.1)
pyautogui.write("3822\nrhdrhd(tpdhl)_tjdnfeorhddnjs\n15000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)(ehddnjsrjstjftksdjq wntlrghltk)\n",interval=0.1)
pyautogui.write("3822\nehddnjsrjstjftksdjq wntlrghltk\n3000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)(ehddnjsrjstjftksdjq wntlrghltk)\n",interval=0.1)
pyautogui.write("3822\nehddnjsrjstjftksdjq wntlrghltk\n3000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n6000\n\nNHzkem(5531810226434883)(ejzofht rlflswja)\n",interval=0.1)
pyautogui.write("3811\nejzofht rlflswja\n6000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n4410900\n\n(rldjq)47501811204011 dpaelzh2018susqns\n",interval=0.1)
pyautogui.write("410800187\n \n4410900\n\nwntlrghltk dpaelzh aocnf dlqrma\n",interval=0.1)
pyautogui.write("425300195\n \n31400\n\nNHzkem(5531810226434883)(rkdskaguseoclrhkdmldnjs)\n",interval=0.1)
pyautogui.write("3811\nrkdskaguseoclrhkdmldnjs\n31400\n\nrhdbswls eovy quddnjsclfy\n",interval=0.1)
pyautogui.write("425300195\n \n4700\n\nNHzkem(5531810226434883)(xlajsl qjqdlsxortl)\n",interval=0.1)
pyautogui.write("3812\nxlajsl qjqdlsxortl\n4700\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n10600\n\nNHzkem(5531810226434883)(xlajsl rodlsxortl dudtp)\n",interval=0.1)
pyautogui.write("3812\nxlajsl rodlsxortl dudtp\n10600\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n25500\n\nNHzkem(5531810226434883)((wn)tmxkqjrtmzjvlzhfldk)\n",interval=0.1)
pyautogui.write("3811\n(wn)tmxkqjrtmzjvlzhfldk\n25500\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300195\n \n12900\n\nNHzkem(5531810226434883)(BKRqjzjzld rkdskaNCwja)\n",interval=0.1)
pyautogui.write("3811\nBKRqjzjzld rkdskaNCwja\n12900\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n4830500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n4830000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)(gksdnflqhghwkrdjqwkd(godqhrgks qpdlzjfl&zk\n",interval=0.1)
pyautogui.write("3811\ngksdnflqhghwkrdjqwkd(godqhrgks qpdlzjfl&zkvp)\n12000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n5500\n\nNHzkem(5531810226434883)(gksrnrwjdqhxhdtls_tjchrncjd)\n",interval=0.1)
pyautogui.write("3822\ngksrnrwjdqhxhdtls_tjchrncjd\n5500\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("310398000\n \n4000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n4000000\n\ndPdlfxhxkfTkdls(wn) aocnfdlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011 SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\nrldjqdmsgod dlqcnfrma xhdwltntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP904\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n4dnjf Serp tkdydfy\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1899647\n\ngytjd CNCwkdql fltmfy 36ghlwnd 13ghl skqqn(wksdor:75,898,276)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n317674\n\ngytjd CNCwkdql fltmfy 36ghlwnd 13ghl skqqn/dlwkqldyd\n",interval=0.1)
pyautogui.write("410398000\n \n337040\n\n(rldjq)47501811204011 rnralsdusrma1904\n",interval=0.1)
pyautogui.write("325400167\n \n168520\n\n4dnjf rnralsdusrma(rmsfhwk qnekarma)\n",interval=0.1)
pyautogui.write("381700167\n \n168520\n\n4dnjf rnralsdusrma(ghltk qnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n273360\n\n(rldjq)47501811204011 rnralsrjsrkd1904\n",interval=0.1)
pyautogui.write("325400168\n \n136680\n\n4dnjf rjsrkdqhgjafy(rmsfhwk qnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n136680\n\n4dnjf rjsrkdqhgjafy(ghltk qnekarma)\n",interval=0.1)
pyautogui.write("425300195\n \n8600\n\nNHzkem(5531810226434883)(roffjflK)\n",interval=0.1)
pyautogui.write("3822\nroffjflK\n8600\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("310398000\n \n6000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n6000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n6600500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n6600000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n18000\n\nNHzkem(5531810226434883)((wn) vldpaqldpvmqmdlghfeldtm)\n",interval=0.1)
pyautogui.write("3811\n(wn) vldpaqldpvmqmdlghfeldtm\n18000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n13800\n\nNHzkem(5531810226434883)(rkdskaguseoclrhkdmldnjs)\n",interval=0.1)
pyautogui.write("3811\nrkdskaguseoclrhkdmldnjs\n13800\n\nrhdbswls eovy quddnjsclfy\n",interval=0.1)
pyautogui.write("410398000\n \n415200\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n415200\n\n5dnjf shdguqzkem eormawlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n50000\n\nNHzkem(5531810226434883)(shdguqdbxhd gkskfh wndbth)\n",interval=0.1)
pyautogui.write("3822\nshdguqdbxhd gkskfh wndbth\n50000\n\nrhdbswls eovy wndbeo\n",interval=0.1)
pyautogui.write("425300195\n \n9600\n\nNHzkem(5531810226434883)(wpfkspdlcj wntlrghltk)\n",interval=0.1)
pyautogui.write("3811\nwpfkspdlcj wntlrghltk\n9600\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)((wn)ehdtla)\n",interval=0.1)
pyautogui.write("3811\n(wn)ehdtla\n12000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n1000\n\nNHzkem(5531810226434883)(wldptmvkzm24(wn)qksvhwp2wnckwkd)\n",interval=0.1)
pyautogui.write("3822\nwldptmvkzm24(wn)qksvhwp2wnckwkd\n1000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n26000\n\nNHzkem(5531810226434883)(gksrkdclzls)\n",interval=0.1)
pyautogui.write("3811\ngksrkdclzls\n26000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n13700\n\nNHzkem(5531810226434883)(fhteptyvld(wn)fhtepakxm tjchwja clwmdos\n",interval=0.1)
pyautogui.write("3811\nfhteptyvld(wn)fhtepakxm tjchwja clwmdosehdn(\n13700\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n4000\n\nNHzkem(5531810226434883)(KCP-rufwp_vkzldzmffkdnem(wn))\n",interval=0.1)
pyautogui.write("3811\nKCP-rufwp_vkzldzmffkdnem(wn)\n4000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n19000\n\nNHzkem(5531810226434883)(aotehffhaks)\n",interval=0.1)
pyautogui.write("3811\naotehffhaks\n19000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n69130\n\nNHzkem(5531810226434883)(SKTdyrmaskqqn)\n",interval=0.1)
pyautogui.write("3814\nSKTdyrmaskqqn\n69130\n\nxhdtlsql-gosemvhs dyrma skqqn\n",interval=0.1)
pyautogui.write("310398000\n \n12000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n12000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n5dnjf dlaeofy wlrmq(dpfTmfl)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n397890\n\n(rldjq)47501811204011 05dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n349918\n\n5dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n11760\n\n5dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n8\n\n5dnjf dpfTmfl wjsfurql dnjseksdnlwjftk\n",interval=0.1)
pyautogui.write("325300199\n \n36220\n\n5dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n36220\n\n5dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n36220\n\n5dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("410398000\n \n30440\n\n(rldjq)47501811204011 tneh1905\n",interval=0.1)
pyautogui.write("3815\n\n30440\n\n5dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("380200207\n \n3100000\n\n5dnjfqns rmqdu(rhdbswls)\n",interval=0.1)
pyautogui.write("425400168\n \n96900\n\n5dnjfqns rjsrkdqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n135000\n\n5dnjfqns rnralsdusrmaqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400191\n \n19500\n\n5dnjfqns rhdydqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n8240\n\n5dnjfqns wkdrldydidqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n5dnjfqns rkqrmstpdhl\n",interval=0.1)
pyautogui.write("425300207\n \n2747030\n\n5dnjf rmqdu alwlrmqqns(rhdbswls)\n",interval=0.1)
pyautogui.write("3802\ndlwodyd\n1000000\n\n5dnjfqns rmqdu(dlwodyd)\n",interval=0.1)
pyautogui.write("425400168\n \n29070\n\n5dnjfqns rjsrkdqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n33520\n\n5dnjfqns rnralsdusrmaqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400191\n \n5850\n\n5dnjfqns rhdydqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n2470\n\n5dnjfqns wkdrldydidqhgjafy qhsdlsqnekarma\n",interval=0.1)
pyautogui.write("4253\ndlwodyd\n929090\n\n5dnjfqns rmqdu alwlrmqqns(dlwodyd)\n",interval=0.1)
pyautogui.write("410398000\n \n24490\n\n(rldjq)47501811204011 tneh1906\n",interval=0.1)
pyautogui.write("3815\n\n24490\n\n6dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("410398000\n \n363890\n\n(rldjq)47501811204011 06dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n315091\n\n6dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n10590\n\n6dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n1\n\n6dnjf dpfTmfl wjsfurql dnjseksdnlwjftk\n",interval=0.1)
pyautogui.write("325300199\n \n38210\n\n6dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n38210\n\n6dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n38210\n\n6dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300195\n \n17500\n\nNHzkem(5531810226434883)(teruwa(Epfndhk)(dnaus1ghwja))\n",interval=0.1)
pyautogui.write("3811\nteruwa(Epfndhk)(dnaus1ghwja)\n17500\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n23200\n\nNHzkem(5531810226434883)(thffktm)\n",interval=0.1)
pyautogui.write("3811\nthffktm\n23200\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n110600\n\nNHzkem(5531810226434883)(qkfmaltiqmtiqmdoszkfrnrtn)\n",interval=0.1)
pyautogui.write("3811\nqkfmaltiqmtiqmdoszkfrnrtn\n110600\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n22000\n\nNHzkem(5531810226434883)(qnskqls)\n",interval=0.1)
pyautogui.write("3811\nqnskqls\n22000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("410398000\n \n700500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n700000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n9100\n\nNHzkem(5531810226434883)(sbzhdkdkdnffptrkdskawja)\n",interval=0.1)
pyautogui.write("3811\nsbzhdkdkdnffptrkdskawja\n9100\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n22900\n\nNHzkem(5531810226434883)(sbzhdkdkdnffptrkdskawja)\n",interval=0.1)
pyautogui.write("3811\nsbzhdkdkdnffptrkdskawja\n22900\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("310398000\n \n8000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n8000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011 SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\nrldjqdmsgod dlqcnfrma xhdwltntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n2747030\n\n(rldjq)47501811204011 rhdbswls\n",interval=0.1)
pyautogui.write("325300166\n \n2747030\n\nrhdbswls 6dnjf rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n929090\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("325300166\n \n929090\n\ndlwodyd 6dnjf rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n337040\n\n(rldjq)47501811204011 rnralsdusrma1906\n",interval=0.1)
pyautogui.write("325400167\n \n168520\n\n6dnjf rnralsdusrma (rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381700167\n \n168520\n\n6dnjf rnralsdusrma (ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1915192\n\ngytjd CNCwkdql fltmfy(36ghlwnd/15ghl) skqqn(wksdor:72,075,680)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n302129\n\ngytjd CNCwkdql fltmfy(36ghlwnd/15ghl) skqqn/dlwkqldyd\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP906\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n6dnjf Serp tkdydfy wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n273360\n\n(rldjq)47501811204011 rnralsrjsrkd1906\n",interval=0.1)
pyautogui.write("325400168\n \n136680\n\n6dnjf rjsrkdqhgjafy (rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n136680\n\n6dnjf rjsrkdqhgjafy (ghltkqnekarma)\n",interval=0.1)
pyautogui.write("425300195\n \n9000\n\nNHzkem(5531810226434883)(vktmznWl didwotkdhrwja)\n",interval=0.1)
pyautogui.write("3811\nvktmznWl didwotkdhrwja\n9000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n28000\n\nNHzkem(5531810226434883)(djauddldy)\n",interval=0.1)
pyautogui.write("3811\ndjauddldy\n28000\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300195\n \n25200\n\nNHzkem(5531810226434883)(CU xhdehqmffnwja)\n",interval=0.1)
pyautogui.write("3811\nCU xhdehqmffnwja\n25200\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("425300301\n \n65500\n\nguseozkem(5531420019433314)(vltnldosclrtm)\n",interval=0.1)
pyautogui.write("3811\nvltnldosclrtm\n65500\n\nrmsfhwk ghltlr\n",interval=0.1)
pyautogui.write("425300195\n \n190500\n\nNHzkem(5531810226434883)((wn)ehddlfflwhxm)\n",interval=0.1)
pyautogui.write("3813\n(wn)ehddlfflwhxm\n190500\n\nrhdbswls eovysla wjqeoql\n",interval=0.1)
pyautogui.write("425300195\n \n9620\n\nNHzkem(5531810226434883)(dlakxm24 qntksthdehqlclwja)\n",interval=0.1)
pyautogui.write("3811\ndlakxm24 qntksthdehqlclwja\n9620\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("410398000\n \n273830\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n273830\n\n7dnjf shdguqzkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n7600\n\nNHzkem(5531810226434883)(zhfpdlfdbxhd(wn)qntksqhsqn)\n",interval=0.1)
pyautogui.write("3812\nzhfpdlfdbxhd(wn)qntksqhsqn\n7600\n\nrhdbswls eovysla ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n14500\n\nNHzkem(5531810226434883)((wn)tmxkqjrtmzjvlzhfldk)\n",interval=0.1)
pyautogui.write("3811\n(wn)tmxkqjrtmzjvlzhfldk\n14500\n\nrhdbswls eovysla qhrflgntodql\n",interval=0.1)
pyautogui.write("410398000\n \n5000\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("3831\n\n5000\n\ndlsrkawmdaudtj 5xhd qkfrmq\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)((wn)tlstprPtpsxmfjftlxl)\n",interval=0.1)
pyautogui.write("3822\n(wn)tlstprPtpsxmfjftlxl\n3000\n\nrhdbswls eovysla wnckql\n",interval=0.1)
pyautogui.write("310398000\n \n4000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n4000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n509690\n\n(rldjq)47501811204011 rnrtp_dpfTmflwntlrghl\n",interval=0.1)
pyautogui.write("3261\nqnrktp\n509690\n\n2019sus 1rlghkrwjd qnrktp\n",interval=0.1)
pyautogui.write("410398000\n \n3480500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n3480000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n96000\n\nNHzkem(5531810226434883)(eogksgkdrhdrlsovksaodnjsghk)\n",interval=0.1)
pyautogui.write("3811\neogksgkdrhdrlsovksaodnjsghk\n96000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n28000\n\nNHzkem(5531810226434883)(tmtldud)\n",interval=0.1)
pyautogui.write("3811\ntmtldud\n28000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n11200\n\nNHzkem(5531810226434883)((wn)rmffhqjfwldps gkssktlrQkd dnauswja)\n",interval=0.1)
pyautogui.write("3811\n(wn)rmffhqjfwldps gkssktlrQkd dnauswja\n11200\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n4000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n4000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n220500\n\n(rldjq)47501811204011 tpanqjqdlsdldnjs\n",interval=0.1)
pyautogui.write("325300218\n \n220000\n\n5dnjf~6dnjf rlwkdfy alwlrmqrma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n7dnjf dlaeofy wlrmq(dltnsska)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n14080\n\n(rldjq)47501811204011 tneh1907\n",interval=0.1)
pyautogui.write("3815\n\n14080\n\n7dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("410398000\n \n370890\n\n(rldjq)47501811204011 07dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n322883\n\n7dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n10860\n\n7dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n3\n\n7dnjf dpfTmfl wjsfurql dnjseksdnl wjftk\n",interval=0.1)
pyautogui.write("325300199\n \n37150\n\n7dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n37150\n\n7dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n37150\n\n7dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("380200166\n \n4100000\n\n7dnjf dpfTmfl wlrdnjs rmqdu\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n7dnjf rkqrmstp\n",interval=0.1)
pyautogui.write("425400168\n \n125970\n\n7dnjf rjsrkdqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n166180\n\n7dnjf rnralsdusrmafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n10710\n\n7dnjf wkdrldydidqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400191\n \n-358900\n\n2018sus 1dnjf~2019sus 6dnjf rhdydqhgjafy rhkdhskqqns ghksrmq\n",interval=0.1)
pyautogui.write("425300166\n \n4062710\n\n7dnjf dpfTmfl wlrdnjs rmqdu alwlrmqrma\n",interval=0.1)
pyautogui.write("310398000\n \n247710\n\n(rldjq)47501811204011 rhkdhskqtkswo\n",interval=0.1)
pyautogui.write("4930\ntkswoqhgja\n247710\n\n2018suseh qkrgusska tkdtlftlsrh snfkrqns\n",interval=0.1)
pyautogui.write("310398000\n \n58690\n\n(rldjq)47501811204011 rhkdhskqrhdyd\n",interval=0.1)
pyautogui.write("493000191\n \n58690\n\n2018suseh qkrgusska tkdtlftlsrh snfkrqns\n",interval=0.1)
pyautogui.write("310398000\n \n14110\n\n(rldjq)47501811204011 rhkdhskqdlaco\n",interval=0.1)
pyautogui.write("493000191\n \n14110\n\n2018suseh qkrgusska tkdtlftlsrh snfkrqns\n",interval=0.1)
pyautogui.write("310398000\n \n305290\n\n(rldjq)47501811204011 rhkdhskqtlfdjq\n",interval=0.1)
pyautogui.write("493000191\n \n305290\n\n2018suseh qkrgusska tkdtlftlsrh snfkrqns\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)(sbrmflsakxm)\n",interval=0.1)
pyautogui.write("3811\nsbrmflsakxm\n12000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n30000\n\nNHzkem(5531810226434883)(eotjdtjrdb(wn)dusdlfwndbth)\n",interval=0.1)
pyautogui.write("3822\neotjdtjrdb(wn)dusdlfwndbth\n30000\n\nrhdbswls eovysla wndbeo\n",interval=0.1)
pyautogui.write("425300195\n \n1057960\n\nNHzkem(5531810226434883)(tkatjdghkwogotkdqhgja(wn))\n",interval=0.1)
pyautogui.write("3821\ntkatjdghkwogotkdqhgja(wn)\n1057960\n\nrhdbswls eovysla gotkdqhgja\n",interval=0.1)
pyautogui.write("425300195\n \n13000\n\nNHzkem(5531810226434883)((wn)tlstprPqorghkwja rkdskawja)\n",interval=0.1)
pyautogui.write("3811\n(wn)tlstprPqorghkwja rkdskawja\n13000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n7000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n7000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n3009700\n\n(rldjq)47501811204011 rhdbswls\n",interval=0.1)
pyautogui.write("325300166\n \n3009700\n\n7dnjf rhdbswls rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n1053010\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("325300166\n \n1053010\n\n7dnjf dlwodyd rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011 SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\nrldjqdmsgod dlqcnfrma xhdwltntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n273360\n\n(rldjq)47501811204011 rnralsrjsrkd1907\n",interval=0.1)
pyautogui.write("325400168\n \n136680\n\n7dnjf rnralsrjsrkdqhgja(rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n136680\n\n7dnjf rnralsrjsrkdqhgja(ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1923012\n\ngytjd CNCwkdql fltmfy(36ghlwnd/16ghl) skqqn(wksdor:70,152,668)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n294309\n\ngytjd CNCwkdql fltmfy(36ghlwnd/16ghl) skqqn/dlwkqldyd\n",interval=0.1)
pyautogui.write("410398000\n \n332360\n\n(rldjq)47501811204011 rnralsdusrma1907\n",interval=0.1)
pyautogui.write("325400167\n \n166180\n\n7dnjf rnralsdusrmaqhgja(rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381700167\n \n166180\n\n7dnjf rnralsdusrmaqhgja(ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP907\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n7dnjf Serp tkdydfy\n",interval=0.1)
pyautogui.write("425300195\n \n52000\n\nNHzkem(5531810226434883)(gksrnrghlrhks)\n",interval=0.1)
pyautogui.write("3811\ngksrnrghlrhks\n52000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n32000\n\nNHzkem(5531810226434883)(tksemfgo)\n",interval=0.1)
pyautogui.write("3811\ntksemfgo\n32000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n11300\n\nNHzkem(5531810226434883)(zjvlqlszhfldk didwotmvhxkdlawja)\n",interval=0.1)
pyautogui.write("3811\nzjvlqlszhfldk didwotmvhxkdlawja\n11300\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n3000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n3000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n4180500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n4180000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n2890\n\nNHzkem(5531810226434883)(dnwjdtkdjqqhsqn(dncprnr))\n",interval=0.1)
pyautogui.write("3514\ndnwjdtkdjqqhsqn(dncprnr)\n2890\n\nrhdbswls eovysla dnvusqkfthd\n",interval=0.1)
pyautogui.write("410398000\n \n515520\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n515520\n\n8dnjf shdguqzkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n10000\n\nNHzkem(5531810226434883)((wn)ehdtla)\n",interval=0.1)
pyautogui.write("3811\n(wn)ehdtla\n10000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n65500\n\n(rldjq)47501811204011 guseozkem08\n",interval=0.1)
pyautogui.write("325300301\n \n65500\n\n8dnjf guseozkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n3800\n\nNHzkem(5531810226434883)(wbTl rnqksvhwja)\n",interval=0.1)
pyautogui.write("3811\nwbTl rnqksvhwja\n3800\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300195\n \n50000\n\nNHzkem(5531810226434883)((wn) dpdlcldoseldl aksskadmlrhkdwkdwndbth)\n",interval=0.1)
pyautogui.write("3811\n(wn) dpdlcldoseldl aksskadmlrhkdwkdwndbth\n50000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n42000\n\nNHzkem(5531810226434883)(tnsskatlforl(tjchrncjdwja))\n",interval=0.1)
pyautogui.write("3811\ntnsskatlforl(tjchrncjdwja)\n42000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300301\n \n22000\n\nguseozkem(5531420019433314)(coeka)\n",interval=0.1)
pyautogui.write("3811\ncoeka\n22000\n\nrhdbswls eovysla tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n4600\n\nNHzkem(5531810226434883)((wn)xlajsl qjqdlsxortl)\n",interval=0.1)
pyautogui.write("3812\n(wn)xlajsl qjqdlsxortl\n4600\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("310398000\n \n5000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n5000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n55500\n\n(rldjq)47501811204011 dpfTmflwntlrghltk(ska\n",interval=0.1)
pyautogui.write("3817\n\n55000\n\ndpfTmfl 2019sus wnalstp(rbsemdqns)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n8dnjf dlaeofy wlrmq(dltnsska)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n2490500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n2490000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("310398000\n \n2000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n2000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("380200166\n \n4100000\n\n8dnjf dpfTmfl wlrdnjsrmqdu\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n8dnjf rkqrmstp\n",interval=0.1)
pyautogui.write("425400168\n \n125970\n\n8dnjf rjsrkdqhgja rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n166180\n\n8dnjf rnralsdusrma rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n10710\n\n8dnjf wkdrldydidqhgja rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425300166\n \n3703810\n\n8dnjf dpfTmfl wlrdnjsrmqdu alwlrmqrma\n",interval=0.1)
pyautogui.write("425300195\n \n13700\n\nNHzkem(5531810226434883)((wn)eocjdtksdjqroqkf tlghkwhfuransghkrhksgbrp\n",interval=0.1)
pyautogui.write("3811\n(wn)eocjdtksdjqroqkf tlghkwhfuransghkrhksgbrpth\n13700\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n8400\n\nNHzkem(5531810226434883)(altmtkdlrhd)\n",interval=0.1)
pyautogui.write("3811\naltmtkdlrhd\n8400\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n2210\n\n(rldjq)47501811204011 tneh1908\n",interval=0.1)
pyautogui.write("3815\n\n2210\n\n8dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("410398000\n \n483370\n\n(rldjq)47501811204011 08dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n404958\n\n8dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n13620\n\n8dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n8\n\n8dnjf dpfTmfl wjsfurql dnjseksdnl wjftk\n",interval=0.1)
pyautogui.write("325300199\n \n64800\n\n8dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n64800\n\n8dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n64800\n\n8dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300195\n \n13000\n\nNHzkem(5531810226434883)(aotehffhaks)\n",interval=0.1)
pyautogui.write("3811\naotehffhaks\n13000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n8800\n\nNHzkem(5531810226434883)((wn)dpdlcldoseldltjdnfaksskadmlrhkdwkdgbrp\n",interval=0.1)
pyautogui.write("3811\n(wn)dpdlcldoseldltjdnfaksskadmlrhkdwkdgbrpth\n8800\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300301\n \n7400\n\nguseozkem(5531420015944207)(zhtmxmzhzhfldk)\n",interval=0.1)
pyautogui.write("3811\nzhtmxmzhzhfldk\n7400\n\nwlrdnjs zjvldhl rnao\n",interval=0.1)
pyautogui.write("425300301\n \n195140\n\nguseozkem(5531420015944207)(zhtmxmzhzhfldk)\n",interval=0.1)
pyautogui.write("3811\nzhtmxmzhzhfldk\n195140\n\nwlrdnjs zjvldhl rnao\n",interval=0.1)
pyautogui.write("425300301\n \n1000\n\nguseozkem(5531420015944207)(zhtmxmzhzhfldk)\n",interval=0.1)
pyautogui.write("3811\nzhtmxmzhzhfldk\n1000\n\nwlrdnjs zjvldhl rnao\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\nrldjqdmsgod SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("310398000\n \n8000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n8000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n934710\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("325300166\n \n934710\n\n8dnjf dlwodyd rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n2769100\n\n(rldjq)47501811204011 rhdbswls\n",interval=0.1)
pyautogui.write("325300166\n \n2769100\n\n8dnjf rhdbswls rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1930865\n\ngytjd CNCwkdql fltmfy(36ghlwnd/17ghl) skqqn(wksdor:68,221,803)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n286456\n\ngytjd CNCwkdql fltmfy(36ghlwnd/17ghl) skqqn/dlwkqldyd\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP908\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n8dnjf Serp tkdydfy\n",interval=0.1)
pyautogui.write("410398000\n \n332360\n\n(rldjq)47501811204011 rnralsdusrma1908\n",interval=0.1)
pyautogui.write("325400167\n \n166180\n\n8dnjf rnralsdusrmaqhgja(rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381700167\n \n166180\n\n8dnjf rnralsdusrmaqhgja(ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n273360\n\n(rldjq)47501811204011 rnralsrjsrkd1908\n",interval=0.1)
pyautogui.write("325400168\n \n136680\n\n8dnjf rjsrkdqhgjafy(rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n136680\n\n8dnjf rjsrkdqhgjafy(ghltkqnekarma)\n",interval=0.1)
pyautogui.write("425300195\n \n38000\n\nNHzkem(5531810226434883)(dlghktnwjsxhddbrrowkd)\n",interval=0.1)
pyautogui.write("3811\ndlghktnwjsxhddbrrowkd\n38000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n1356350\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n1356350\n\n9dnjf shdguqzkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n44385\n\nNHzkem(5531810226434883)((wn) dpdlcldoseldl aksskadmlrhkdwkdwndbth)\n",interval=0.1)
pyautogui.write("3811\n(wn) dpdlcldoseldl aksskadmlrhkdwkdwndbth\n44385\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n8100\n\nNHzkem(5531810226434883)((wn)xlajsl rodlsxortl dudtp)\n",interval=0.1)
pyautogui.write("3812\n(wn)xlajsl rodlsxortl dudtp\n8100\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("410398000\n \n22000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300301\n \n22000\n\n9dnjf guseozkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n5600\n\nNHzkem(5531810226434883)((wn)xlajsl qjqdlsxortl)\n",interval=0.1)
pyautogui.write("3812\n(wn)xlajsl qjqdlsxortl\n5600\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n7400\n\nNHzkem(5531810226434883)((wn)xlajsl rodlsxortl dudtp)\n",interval=0.1)
pyautogui.write("3812\n(wn)xlajsl rodlsxortl dudtp\n7400\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("310398000\n \n678\n\n(rldjq)47501811204011 2019susruftks\n",interval=0.1)
pyautogui.write("490198000\n \n678\n\nrldjqdmsgod dlwktndlr\n",interval=0.1)
pyautogui.write("310398000\n \n8000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n8000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n7540500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n7540000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n10000\n\nNHzkem(5531810226434883)(vkvktmqmfhxm)\n",interval=0.1)
pyautogui.write("3811\nvkvktmqmfhxm\n10000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n8000000\n\n(rldjq)47501811204011 wntlrghltkwlektvl\n",interval=0.1)
pyautogui.write("410800219\n \n8000000\n\n\n",interval=0.1)
pyautogui.write("425300195\n \n15200\n\nNHzkem(5531810226434883)((wn)tmxkqjrtmzjvlzhfldk)\n",interval=0.1)
pyautogui.write("3811\n(wn)tmxkqjrtmzjvlzhfldk\n15200\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n110000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300104\n \n110000\n\ndlswmdtjrodtls\n",interval=0.1)
pyautogui.write("425300195\n \n13000\n\nNHzkem(5531810226434883)((wn)rmffhqjfwldps gkssktlrQkd dnauswja)\n",interval=0.1)
pyautogui.write("3811\n(wn)rmffhqjfwldps gkssktlrQkd dnauswja\n13000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300301\n \n105960\n\nguseozkem(5531420019433314)(zhtmxmzhzhfldk)\n",interval=0.1)
pyautogui.write("3811\nzhtmxmzhzhfldk\n105960\n\nwlrdnjs zjvldhl rnao\n",interval=0.1)
pyautogui.write("410398000\n \n110500\n\n(rldjq)47501811204011 tpanqjqdlsdldnjs\n",interval=0.1)
pyautogui.write("325300218\n \n110000\n\n7dnjf rlwkdfy alwlrmqrma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n110500\n\n(rldjq)47501811204011 tpanqjqdlsdldnjsthdvkwl\n",interval=0.1)
pyautogui.write("325300220\n \n110000\n\n8dnjf rlwkdfy alwlrmqrma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n9dnjf dlaeofy wlrmq(dltnsska)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n6660\n\n(rldjq)47501811204011 tneh1909\n",interval=0.1)
pyautogui.write("3815\n\n6660\n\n9dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("410398000\n \n412820\n\n(rldjq)47501811204011 09dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n350177\n\n9dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n11770\n\n9dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n7\n\n9dnjf dpfTmfl wjsfurql dnjseksdnl wjftk\n",interval=0.1)
pyautogui.write("325300199\n \n50880\n\n9dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n50880\n\n9dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n50880\n\n9dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("380200166\n \n4100000\n\n9dnjf dpfTmfl wlrdnjsrmqdu\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n9dnjf rkqrmstp\n",interval=0.1)
pyautogui.write("425400168\n \n125970\n\n9dnjf rjsrkdqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n166180\n\n9dnjf rnralsdusrmafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n10710\n\n9dnjf wkdrldydidqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425300166\n \n3703810\n\n9dnjf dpfTmfl wlrdnjsrmqdu alwlrmqrma\n",interval=0.1)
pyautogui.write("425300195\n \n2800\n\nNHzkem(5531810226434883)(wldptmvkzm24(wn)qksvhwp2wnckwkd)\n",interval=0.1)
pyautogui.write("3812\nwldptmvkzm24(wn)qksvhwp2wnckwkd\n2800\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("410398000\n \n3000\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("3831\n\n3000\n\ndlsrkawmdaudtj 3xhd qkfrmq-dlwodyd\n",interval=0.1)
pyautogui.write("425300195\n \n4900\n\nNHzkem(5531810226434883)((wn)xlajsl qjqdlsxortl)\n",interval=0.1)
pyautogui.write("3812\n(wn)xlajsl qjqdlsxortl\n4900\n\nrhdbswls eovy ryxhdql\n",interval=0.1)
pyautogui.write("425300195\n \n25500\n\nNHzkem(5531810226434883)(dlxmckdlsk)\n",interval=0.1)
pyautogui.write("3811\ndlxmckdlsk\n25500\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n2000\n\nNHzkem(5531810226434883)((gkr)rkxhfflreogkrrytjdnftjdahquddnjs)\n",interval=0.1)
pyautogui.write("3822\n(gkr)rkxhfflreogkrrytjdnftjdahquddnjs\n2000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n15000\n\nNHzkem(5531810226434883)(cjdwjdghltwlq)\n",interval=0.1)
pyautogui.write("3811\ncjdwjdghltwlq\n15000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)(aleh)\n",interval=0.1)
pyautogui.write("3811\naleh\n3000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n165500\n\n(rldjq)47501811204011 ckgusal\n",interval=0.1)
pyautogui.write("325300221\n \n165000\n\nckfid qoxjfl tnflqldyd\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)((gkr)rkxhfflreogkrrytjdnftjdahquddnjs)\n",interval=0.1)
pyautogui.write("3822\n(gkr)rkxhfflreogkrrytjdnftjdahquddnjs\n3000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)((gkr)rkxhfflreogkrrytjdnftjdahquddnjs)\n",interval=0.1)
pyautogui.write("3822\n(gkr)rkxhfflreogkrrytjdnftjdahquddnjs\n3000\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n13000\n\nNHzkem(5531810226434883)(xpfldiRl)\n",interval=0.1)
pyautogui.write("3811\nxpfldiRl\n13000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n27000\n\nNHzkem(5531810226434883)(shffkdns djaakdml qndjz(WOWMOM'S KITCHEN\n",interval=0.1)
pyautogui.write("3811\nshffkdns djaakdml qndjz(WOWMOM'S KITCHEN)\n27000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n3000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n3000000\n\n\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\n9dnjf SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n2769100\n\n(rldjq)47501811204011 rhdbswls\n",interval=0.1)
pyautogui.write("325300166\n \n2769100\n\n9dnjf rhdbswls rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n934710\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("325300166\n \n934710\n\n9dnjf dlwodyd rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1938749\n\ngytjd CNCwkdql fltmfy(36ghlwnd/18ghl) skqqn(wksdor:66,283,054)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n278572\n\ngytjd CNCwkdql fltmfy(36ghlwnd/18ghl) skqqn(wksdor:66,283,054)\n",interval=0.1)
pyautogui.write("410398000\n \n332360\n\n(rldjq)47501811204011 rnralsdusrma1909\n",interval=0.1)
pyautogui.write("325400167\n \n166180\n\n9dnjfqns rnralsdusrmafy (rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381700167\n \n166180\n\n9dnjfqns rnralsdusrmafy (ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n277320\n\n(rldjq)47501811204011 rnralsrjsrkd1909\n",interval=0.1)
pyautogui.write("325400168\n \n138660\n\n9dnjfqns rjsrkdqhgjafy (rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n138660\n\n9dnjfqns rjsrkdqhgjafy (ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP909\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n\n",interval=0.1)
pyautogui.write("310398000\n \n3200000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n3200000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n3180500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n3180000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n121770\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("381700199\n \n100000\n\n2019sus tkdjqthtp-dltnsskarjsanf\n",interval=0.1)
pyautogui.write("396000199\n \n21770\n\n2019sus tkdjqthtp-dltnsskarjsanf\n",interval=0.1)
pyautogui.write("410398000\n \n247785\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n247785\n\n10dnjf shdguqzkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n16500\n\nNHzkem(5531810226434883)(tmvkrpxltmxhfl)\n",interval=0.1)
pyautogui.write("3811\ntmvkrpxltmxhfl\n16500\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n30000\n\nNHzkem(5531810226434883)(Rhcekfrdo)\n",interval=0.1)
pyautogui.write("3811\nRhcekfrdo\n30000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("410398000\n \n309500\n\n(rldjq)47501811204011 guseozkem10\n",interval=0.1)
pyautogui.write("325300301\n \n309500\n\n10dnjf guseozkem eorma wlrmq\n",interval=0.1)
pyautogui.write("310398000\n \n93530\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("4930\ntkswoqhgja\n93530\n\n2019sus 1~6dnjf rhdyd,tkswo rhkdhskqqns dlqrma\n",interval=0.1)
pyautogui.write("310398000\n \n24610\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("493000191\n \n24610\n\n2019sus 1~6dnjf rhdyd,tkswo rhkdhskqqns dlqrma\n",interval=0.1)
pyautogui.write("310398000\n \n5860\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("493000191\n \n5860\n\n2019sus 1~6dnjf rhdyd,tkswo rhkdhskqqns dlqrma\n",interval=0.1)
pyautogui.write("310398000\n \n128030\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("493000191\n \n128030\n\n\n",interval=0.1)
pyautogui.write("310398000\n \n5000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n5000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n4476030\n\n(rldjq)47501811204011 rnrtp_dpfTmflwntlrghl\n",interval=0.1)
pyautogui.write("3261\nqnrktp\n4476030\n\n2019sus 2rl dPwjd qnrktp skqqn\n",interval=0.1)
pyautogui.write("425300195\n \n50000\n\nNHzkem(5531810226434883)(wntlrghltkzpdldps(rPskawndbth))\n",interval=0.1)
pyautogui.write("3822\nwntlrghltkzpdldps(rPskawndbth)\n50000\n\nrhdbswls eovy wndbeo\n",interval=0.1)
pyautogui.write("310398000\n \n6000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n6000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n5740500\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
pyautogui.write("325100101\n \n5740000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n40000\n\nNHzkem(5531810226434883)(ehrhrshddnjs)\n",interval=0.1)
pyautogui.write("3811\nehrhrshddnjs\n40000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n4000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n4000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n110500\n\n(rldjq)47501811204011 tpanqjqdlsdldnjsthdvkwl\n",interval=0.1)
pyautogui.write("325300220\n \n110000\n\n10dnjf tpanqjqdls dldnjs thdvkwlwja rlwkdfy\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n3520500\n\n(rldjq)47501811204011 dltnsska\n",interval=0.1)
pyautogui.write("325300199\n \n3520000\n\n10dnjf dlaeofy wlrmq(dltnsska)\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n2210\n\n(rldjq)47501811204011 tneh1910\n",interval=0.1)
pyautogui.write("3815\n\n2210\n\n10dnjf tkdgktnehfy\n",interval=0.1)
pyautogui.write("410398000\n \n370450\n\n(rldjq)47501811204011 10dnjfwjsrlfy\n",interval=0.1)
pyautogui.write("325300200\n \n318715\n\n10dnjf dpfTmfl wjsfurql\n",interval=0.1)
pyautogui.write("351600200\n \n10720\n\n10dnjf dpfTmfl wjsfurrlrma\n",interval=0.1)
pyautogui.write("455600200\n \n5\n\n10dnjf dpfTmfl wjsfurql dnjseksdnl wjftk\n",interval=0.1)
pyautogui.write("325300199\n \n41020\n\n10dnjf dltnsska wjsfurql wlrmq\n",interval=0.1)
pyautogui.write("381600199\n \n41020\n\n10dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("425300199\n \n41020\n\n10dnjf wjsfurql(dltnsska)\n",interval=0.1)
pyautogui.write("380200166\n \n4100000\n\n10dnjf dpfTmfl wlrdnjsrmqdu\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n10dnjf dpfTmfl rkqrmstp\n",interval=0.1)
pyautogui.write("425400168\n \n125970\n\n10dnjf dpfTmfl rjsrkdqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n166180\n\n10dnjf dpfTmfl rnralsdusrmafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n10710\n\n10dnjf dpfTmfl wkdrldydidqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425300166\n \n3703810\n\n10dnjf dpfTmfl wlrdnjsrmqdu alwlrmqrma\n",interval=0.1)
pyautogui.write("425300195\n \n5000\n\nNHzkem(5531810226434883)(rkdskaakxm)\n",interval=0.1)
pyautogui.write("3811\nrkdskaakxm\n5000\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("410398000\n \n739750\n\n(rldjq)47501811204011 wntlrghltkdpaelzh\n",interval=0.1)
pyautogui.write("325100187\n \n739750\n\nwntlrghltk dpaelzh eorma wlrmq\n",interval=0.1)
pyautogui.write("310398000\n \n2310000\n\n(rldjq)47501811204011 (wn)dpaelzh\n",interval=0.1)
pyautogui.write("410800187\n \n2310000\n\n\n",interval=0.1)
pyautogui.write("425300195\n \n45628\n\nNHzkem(5531810226434883)((wn) dpdlcldoseldl aksskadmlrhkdwkdwndbth)\n",interval=0.1)
pyautogui.write("3811\n(wn) dpdlcldoseldl aksskadmlrhkdwkdwndbth\n45628\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n3000\n\nNHzkem(5531810226434883)((wn)ckzpdjtm)\n",interval=0.1)
pyautogui.write("3811\n(wn)ckzpdjtm\n3000\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300301\n \n687210\n\nguseozkem(5531420019433314)(zhtmxmzhzhfldk)\n",interval=0.1)
pyautogui.write("3811\nzhtmxmzhzhfldk\n687210\n\ntkantlf zjvldhl rnao\n",interval=0.1)
pyautogui.write("425300195\n \n2100\n\nNHzkem(5531810226434883)(tk)qorqjarlarntjstodrlsuatkdjqguqghl)\n",interval=0.1)
pyautogui.write("3822\ntk)qorqjarlarntjstodrlsuatkdjqguqghl\n2100\n\nrhdbswls eovy wnckql\n",interval=0.1)
pyautogui.write("425300195\n \n7000\n\nNHzkem(5531810226434883)((wn)ckzpdjtm)\n",interval=0.1)
pyautogui.write("3811\n(wn)ckzpdjtm\n7000\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300195\n \n28000\n\nNHzkem(5531810226434883)(tmtldud)\n",interval=0.1)
pyautogui.write("3811\ntmtldud\n28000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n39000\n\nNHzkem(5531810226434883)((wn)shdguqgkskfhdbxhdtjdskashdtksanfwhdgkqdb\n",interval=0.1)
pyautogui.write("3811\n(wn)shdguqgkskfhdbxhdtjdskashdtksanfwhdgkqdbxhdtpsxj\n39000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n6000\n\nNHzkem(5531810226434883)((wn)ckzpdjtm)\n",interval=0.1)
pyautogui.write("3811\n(wn)ckzpdjtm\n6000\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("425300195\n \n18000\n\nNHzkem(5531810226434883)(dlghktnwjsxhddbrrowkd)\n",interval=0.1)
pyautogui.write("3811\ndlghktnwjsxhddbrrowkd\n18000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n7000\n\nNHzkem(5531810226434883)(GS25 tjchgksdnflwja)\n",interval=0.1)
pyautogui.write("3811\nGS25 tjchgksdnflwja\n7000\n\nrhdbswls eovy rkstlr\n",interval=0.1)
pyautogui.write("410398000\n \n900\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("381498000\n \n900\n\n10dnjf SMSxhdwltntnfy\n",interval=0.1)
pyautogui.write("310398000\n \n5000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n5000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n2769100\n\n(rldjq)47501811204011 rhdbswls\n",interval=0.1)
pyautogui.write("325300166\n \n2769100\n\n10dnjf rhdbswls rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n934710\n\n(rldjq)47501811204011 dlwodyd\n",interval=0.1)
pyautogui.write("325300166\n \n934710\n\n10dnjf dlwodyd rmqdu wlrmq\n",interval=0.1)
pyautogui.write("410398000\n \n332360\n\n(rldjq)47501811204011 rnralsdusrma1910\n",interval=0.1)
pyautogui.write("325400167\n \n166180\n\n10dnjf rnralsdusrmafy(rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("3813253001700167\n \n166180\n\n10dnjf rnralsdusrmafy(ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n2217321\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("3293\nHYOSUNG\n1946666\n\ngytjd CNCwkdql fltmfy(36ghlwnd/19ghl) skqqn(wksdor:64,336,388)\n",interval=0.1)
pyautogui.write("3931\nHYOSUNG\n270655\n\ngytjd CNCwkdql fltmfy(36ghlwnd/19ghl) skqqn(wksdor:64,336,388)\n",interval=0.1)
pyautogui.write("410398000\n \n81400\n\n(rldjq)47501811204011 sERP910\n",interval=0.1)
pyautogui.write("3253\ndnpqzptl(wn)\n81400\n\n\n",interval=0.1)
pyautogui.write("410398000\n \n273360\n\n(rldjq)47501811204011 rnralsrjsrkd1910\n",interval=0.1)
pyautogui.write("325400168\n \n136680\n\n10dnjf rjsrkdqhgjafy(rmsfhwkqnekarma)\n",interval=0.1)
pyautogui.write("381100168\n \n136680\n\n10dnjf rjsrkdqhgjafy(ghltkqnekarma)\n",interval=0.1)
pyautogui.write("410398000\n \n190500\n\n(rldjq)47501811204011 rhkddkawndbth\n",interval=0.1)
pyautogui.write("325300222\n \n190000\n\nrhkddkawndbth-tlfsoemddb eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("410398000\n \n183900\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325300195\n \n183900\n\n11dnjf shdguqzkem eorma wlrmq\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)(zlekfltlrvna(wn)wjddksgkgodwlwja)\n",interval=0.1)
pyautogui.write("3811\nzlekfltlrvna(wn)wjddksgkgodwlwja\n12000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("310398000\n \n7000000\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("410800102\n \n7000000\n\ndPdlfxhxkfTkdls(wn) aocnf dlqrma\n",interval=0.1)
pyautogui.write("410398000\n \n6400500\n\n(rldjq)47501811204011\n",interval=0.1)
pyautogui.write("325100101\n \n6400000\n\ngksrnrTmfldpa(wn) eorma wlrmq\n",interval=0.1)
pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
pyautogui.write("425300195\n \n12000\n\nNHzkem(5531810226434883)((wn)xhekzhfldk)\n",interval=0.1)
pyautogui.write("3811\n(wn)xhekzhfldk\n12000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("425300195\n \n30000\n\nNHzkem(5531810226434883)(gksdnflqhghwkrdjqwkd(godqhrgks qpdlzjfl&zk\n",interval=0.1)
pyautogui.write("3811\ngksdnflqhghwkrdjqwkd(godqhrgks qpdlzjfl&zkvp)\n30000\n\nrhdbswls eovy tlreo\n",interval=0.1)
pyautogui.write("380200166\n \n4100000\n\n11dnjf dpfTmfl wlrdnjsrmqdu\n",interval=0.1)
pyautogui.write("425400169\n \n93330\n\n11dnjf dpfTmfl rkqrmstp\n",interval=0.1)
pyautogui.write("425400168\n \n125970\n\n11dnjf dpfTmfl rjsrkdqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400167\n \n166180\n\n11dnjf dpfTmfl rnralsdusrmafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425400168\n \n10710\n\n11dnjf dpfTmfl wkdrldydidqhgjafy rmsfhwkqnekarma\n",interval=0.1)
pyautogui.write("425300166\n \n3703810\n\n11dnjf dpfTmfl wlrdnjsrmqdu alwlrmqrma\n",interval=0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-63d654402f65> in <module>
#      12 pyautogui.write("410398000\n \n2269195\n\n(rldjq)47501811204011 gksrnrTmfldpa(wn)\n",interval=0.1)
#      13 pyautogui.write("325100101\n \n2268695\n\ngksrnrTmfldpa eormawlrmq\n",interval=0.1)
# ---> 14 pyautogui.write("383198000\n \n500\n\nthdrmatntnfy\n",interval=0.1)
#      15 pyautogui.write("425300195\n \n6300\n\nNHzkem(5531810226434883)(xlajslqjqdlsxortl)\n",interval=0.1)
#      16 pyautogui.write("3812\nxlajslqjqdlsxortl\n6300\n\nrhdbswls ryxhdql\n",interval=0.1)
#
# d:\ProgramData\Anaconda3\lib\site-packages\pyautogui\__init__.py in typewrite(message, interval, pause, logScreenshot, _pause)
#    1209             c = c.lower()
#    1210         press(c, _pause=False)
# -> 1211         time.sleep(interval)
#    1212         failSafeCheck()
#    1213
#
# ...

# %%
pyautogui.write("3831\nrudrldhrdhlrhkdrhguqghlskadidwntlwlqn\n74000\n\nGSgksdudwndbth quraus,wlwn tntnfy\n",interval=0.1)
pyautogui.write("4138\nrudrldhrdhlrhkdrhguqghlskadidwntlwlqn\n74000\n\nGSgksdudwndbth quraus,wlwn tntnfy\n",interval=0.1)
pyautogui.write("3831\nrudrldhrdhlrhkdrhguqghlskadidwntlwlqn\n49890\n\nGSgksdudwndbth dkswjseh\n",interval=0.1)
pyautogui.write("4138\nrudrldhrdhlrhkdrhguqghlskadidwntlwlqn\n49890\n\nGSgksdudwndbth dkswjseh\n",interval=0.1)
pyautogui.write("3831\nrudrldhrdhlrhkdrhguqghlskadidwntlwlqn\n22000\n\nGSgksdudwndbth wlwn\n",interval=0.1)
pyautogui.write("4138\nrudrldhrdhlrhkdrhguqghlskadidwntlwlqn\n22000\n\nGSgksdudwndbth wlwn\n",interval=0.1)

# %% [markdown]
# #삼거리식당 30000
# pyautogui.click(gubun)
# pyautogui.write('''351100286\n\n30000\n\nwksdjqtltlreo
# 413800286\n\n30000\n\nwksdjqtltlreo
# ''')

# %%
#삼거리식당 22000
pyautogui.click(gubun)
pyautogui.write('''351100286\n\n22000\n\nwksdjqtltlreo
413800286\n\n22000\n\nwksdjqtltlreo
''')

# %%
#삼거리식당 20000
pyautogui.click(gubun)
pyautogui.write('''351100286\n\n20000\n\nwksdjqtltlreo
413800286\n\n20000\n\nwksdjqtltlreo
''')

# %%
#삼거리식당 5000
pyautogui.click(gubun)
pyautogui.write('''351100286\n\n5000\n\nwksdjqtltlreo
413800286\n\n5000\n\nwksdjqtltlreo
''')

# %%
#삼거리식당 10000
pyautogui.click(gubun)
pyautogui.write('''351100286\n\n10000\n\nwksdjqtltlreo
413800286\n\n10000\n\nwksdjqtltlreo
''')

# %%
a='4138\nwork\n22000\n\nwork22'

pyautogui.click(gubun)
pyautogui.write(a)
pyautogui.press('enter')
pyautogui.press('down')

# %%
pip install pyperclip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 한영타 변환기
# http://www.theyt.net/wiki/%ED%95%9C%EC%98%81%ED%83%80%EB%B3%80%ED%99%98%EA%B8%B0
# https://ontools.kr/text/textKeyboard.php
